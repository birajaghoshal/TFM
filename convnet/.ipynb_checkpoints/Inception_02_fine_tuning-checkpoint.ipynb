# %% [markdown]
# # bottleneck

# %%
# check them out
from keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from keras.models import Sequential
from keras.layers import Dropout, Flatten, Dense
from keras.applications.vgg16 import preprocess_input
from keras.optimizers import SGD
from keras.utils.np_utils import to_categorical
from keras.applications.inception_v3 import InceptionV3
from keras.preprocessing import image
from keras.models import Model
from keras.layers import Dense, GlobalAveragePooling2D
from keras import backend as K

import numpy as np
import math
# Out:
# Using TensorFlow backend.

# %%
PATH_TO_DF = "../data/output_convnet/Inception"

img_width = 150
img_height = 150

n_epochs = 50
batch_size = 16

train_data_dir = "train"  
validation_data_dir = "validation"
test_data_dir = "test"

n_train_samples = 3000
n_validation_samples = 1000
n_test_samples = 1000
n_classes = 8

# %%
# https://b/log.keras.io/building-powerful-image-classification-models-using-very-little-data.html
# saving bottleneck features
import time

ti_bn_features = time.time()

model = InceptionV3(include_top=False, weights='imagenet')

datagen = ImageDataGenerator(rescale=1. / 255)

'''
https://github.com/keras-team/keras/blob/master/keras/preprocessing/image.py#L1002
if PIL version 1.1.3 interpolation = 'lanczos'
else interpolation = 'bicubic' 
''' 

# train
generator = datagen.flow_from_directory(
    train_data_dir,
    target_size = (img_width, img_height),
    batch_size = batch_size,
    class_mode = None,
    shuffle = False,
    interpolation = 'lanczos')

# important step in order to get the exact number
max_queue_size_train = int(math.ceil(n_train_samples / batch_size))

bnfeatures_train = model.predict_generator(
    generator, max_queue_size_train)

np.save('../data/output_convnet/Inception/inception_bnfeatures_train.npy', bnfeatures_train)

# validation
generator = datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode=None,
    shuffle=False,
    interpolation = 'lanczos')

max_queue_size_val = int(math.ceil(n_validation_samples / batch_size))


bnfeatures_val = model.predict_generator(  
     generator, max_queue_size_val)

np.save('../data/output_convnet/Inception/inception_bnfeatures_val.npy', bnfeatures_val)


tf_bn_features = time.time()    
tt_bn_features = tf_bn_features - ti_bn_features
# Out:
# Found 3000 images belonging to 8 classes.
# Found 1000 images belonging to 8 classes.

# %%
print(time.strftime("%H:%M:%S", time.gmtime(tt_bn_features)))
# Out:
# 00:00:26

# %%
# training top layer
import os

ti_bn_train = time.time()

# we have to get the classes names so we build again a generator
datagen_top_layer = ImageDataGenerator(rescale=1./255)  

# train
generator_top_layer = datagen_top_layer.flow_from_directory(
    train_data_dir,  
    target_size=(img_width, img_height),  
    batch_size=batch_size,  
    class_mode='categorical',  
    shuffle=False,
    interpolation = 'lanczos')  

train_data = np.load('../data/output_convnet/Inception/inception_bnfeatures_train.npy')

# ref attribute classes --> https://keras.io/preprocessing/image/
train_labels = generator_top_layer.classes # the key attribute
train_labels = to_categorical(train_labels, num_classes=n_classes) # the key function

# validation
generator_top_layer = datagen_top_layer.flow_from_directory(  
    validation_data_dir,  
    target_size=(img_width, img_height),  
    batch_size=batch_size,  
    class_mode=None,  
    shuffle=False,
    interpolation = 'lanczos')  

val_data = np.load('../data/output_convnet/Inception/inception_bnfeatures_val.npy') 

val_labels = generator_top_layer.classes # the key attribute
val_labels = to_categorical(val_labels, num_classes=n_classes) # the key function


# top model, could be with a diff dense, optimizer, momentum -> https://keras.io/optimizers/
model = Sequential()  
model.add(GlobalAveragePooling2D(input_shape=train_data.shape[1:]))  
model.add(Dense(1024, activation='relu'))  
model.add(Dense(n_classes, activation='softmax'))  

model.compile(optimizer=SGD(lr=0.001),
              loss='categorical_crossentropy', metrics=['accuracy']) 


historical_data = model.fit(train_data, train_labels,
                    epochs=n_epochs,
                    batch_size=batch_size,
                    validation_data=(val_data, val_labels))  

# h5py
model.save_weights('../data/output_convnet/Inception/inception_bn_model.h5')  

tf_bn_train = time.time()    
tt_bn_train = tf_bn_train - ti_bn_train
# Out:
# Found 3000 images belonging to 8 classes.
# Found 1000 images belonging to 8 classes.
# Train on 3000 samples, validate on 1000 samples
# Epoch 1/50
# 3000/3000 [==============================] - 2s 538us/step - loss: 1.7024 - acc: 0.3613 - val_loss: 1.4286 - val_acc: 0.5210
# Epoch 2/50
# 3000/3000 [==============================] - 1s 327us/step - loss: 1.2423 - acc: 0.6540 - val_loss: 1.1950 - val_acc: 0.7050
# Epoch 3/50
# 3000/3000 [==============================] - 1s 347us/step - loss: 1.0505 - acc: 0.7537 - val_loss: 1.0476 - val_acc: 0.7440
# Epoch 4/50
# 3000/3000 [==============================] - 1s 336us/step - loss: 0.9254 - acc: 0.7967 - val_loss: 0.9515 - val_acc: 0.7600
# Epoch 5/50
# 3000/3000 [==============================] - 1s 318us/step - loss: 0.8348 - acc: 0.8117 - val_loss: 0.8774 - val_acc: 0.7850
# Epoch 6/50
# 3000/3000 [==============================] - 1s 319us/step - loss: 0.7648 - acc: 0.8213 - val_loss: 0.8265 - val_acc: 0.7930
# Epoch 7/50
# 3000/3000 [==============================] - 1s 325us/step - loss: 0.7072 - acc: 0.8340 - val_loss: 0.7890 - val_acc: 0.7990
# Epoch 8/50
# 3000/3000 [==============================] - 1s 317us/step - loss: 0.6611 - acc: 0.8460 - val_loss: 0.7536 - val_acc: 0.7990
# Epoch 9/50
# 3000/3000 [==============================] - 1s 329us/step - loss: 0.6216 - acc: 0.8530 - val_loss: 0.7281 - val_acc: 0.8070
# Epoch 10/50
# 3000/3000 [==============================] - 1s 318us/step - loss: 0.5885 - acc: 0.8573 - val_loss: 0.6985 - val_acc: 0.8070
# Epoch 11/50
# 3000/3000 [==============================] - 1s 321us/step - loss: 0.5606 - acc: 0.8637 - val_loss: 0.6782 - val_acc: 0.8100
# Epoch 12/50
# 3000/3000 [==============================] - 1s 324us/step - loss: 0.5339 - acc: 0.8720 - val_loss: 0.6601 - val_acc: 0.8180
# Epoch 13/50
# 3000/3000 [==============================] - 1s 325us/step - loss: 0.5132 - acc: 0.8750 - val_loss: 0.6400 - val_acc: 0.8220
# Epoch 14/50
# 3000/3000 [==============================] - 1s 321us/step - loss: 0.4923 - acc: 0.8810 - val_loss: 0.6282 - val_acc: 0.8230
# Epoch 15/50
# 3000/3000 [==============================] - 1s 329us/step - loss: 0.4740 - acc: 0.8847 - val_loss: 0.6144 - val_acc: 0.8260
# Epoch 16/50
# 3000/3000 [==============================] - 1s 323us/step - loss: 0.4571 - acc: 0.8913 - val_loss: 0.6076 - val_acc: 0.8280
# Epoch 17/50
# 3000/3000 [==============================] - 1s 322us/step - loss: 0.4413 - acc: 0.8937 - val_loss: 0.5928 - val_acc: 0.8300
# Epoch 18/50
# 3000/3000 [==============================] - 1s 321us/step - loss: 0.4279 - acc: 0.8973 - val_loss: 0.5935 - val_acc: 0.8240
# Epoch 19/50
# 3000/3000 [==============================] - 1s 326us/step - loss: 0.4152 - acc: 0.9013 - val_loss: 0.5745 - val_acc: 0.8320
# Epoch 20/50
# 3000/3000 [==============================] - 1s 327us/step - loss: 0.4032 - acc: 0.9063 - val_loss: 0.5701 - val_acc: 0.8300
# Epoch 21/50
# 3000/3000 [==============================] - 1s 321us/step - loss: 0.3917 - acc: 0.9073 - val_loss: 0.5645 - val_acc: 0.8340
# Epoch 22/50
# 3000/3000 [==============================] - 1s 321us/step - loss: 0.3810 - acc: 0.9100 - val_loss: 0.5532 - val_acc: 0.8350
# Epoch 23/50
# 3000/3000 [==============================] - 1s 325us/step - loss: 0.3713 - acc: 0.9133 - val_loss: 0.5554 - val_acc: 0.8300
# Epoch 24/50
# 3000/3000 [==============================] - 1s 351us/step - loss: 0.3611 - acc: 0.9150 - val_loss: 0.5501 - val_acc: 0.8320
# Epoch 25/50
# 3000/3000 [==============================] - 1s 318us/step - loss: 0.3536 - acc: 0.9163 - val_loss: 0.5397 - val_acc: 0.8360
# Epoch 26/50
# 3000/3000 [==============================] - 1s 325us/step - loss: 0.3446 - acc: 0.9190 - val_loss: 0.5356 - val_acc: 0.8360
# Epoch 27/50
# 3000/3000 [==============================] - 1s 324us/step - loss: 0.3369 - acc: 0.9220 - val_loss: 0.5268 - val_acc: 0.8370
# Epoch 28/50
# 3000/3000 [==============================] - 1s 318us/step - loss: 0.3298 - acc: 0.9213 - val_loss: 0.5271 - val_acc: 0.8370
# Epoch 29/50
# 3000/3000 [==============================] - 1s 326us/step - loss: 0.3224 - acc: 0.9253 - val_loss: 0.5217 - val_acc: 0.8380
# Epoch 30/50
# 3000/3000 [==============================] - 1s 322us/step - loss: 0.3156 - acc: 0.9253 - val_loss: 0.5229 - val_acc: 0.8370
# Epoch 31/50
# 3000/3000 [==============================] - 1s 321us/step - loss: 0.3093 - acc: 0.9263 - val_loss: 0.5164 - val_acc: 0.8380
# Epoch 32/50
# 3000/3000 [==============================] - 1s 325us/step - loss: 0.3033 - acc: 0.9267 - val_loss: 0.5122 - val_acc: 0.8390
# Epoch 33/50
# 3000/3000 [==============================] - 1s 350us/step - loss: 0.2968 - acc: 0.9303 - val_loss: 0.5109 - val_acc: 0.8380
# Epoch 34/50
# 3000/3000 [==============================] - 1s 367us/step - loss: 0.2918 - acc: 0.9323 - val_loss: 0.5046 - val_acc: 0.8390
# Epoch 35/50
# 3000/3000 [==============================] - 1s 315us/step - loss: 0.2865 - acc: 0.9343 - val_loss: 0.5034 - val_acc: 0.8350
# Epoch 36/50
# 3000/3000 [==============================] - 1s 311us/step - loss: 0.2808 - acc: 0.9360 - val_loss: 0.5018 - val_acc: 0.8400
# Epoch 37/50
# 3000/3000 [==============================] - 1s 331us/step - loss: 0.2758 - acc: 0.9377 - val_loss: 0.4994 - val_acc: 0.8380
# Epoch 38/50
# 3000/3000 [==============================] - 1s 318us/step - loss: 0.2711 - acc: 0.9390 - val_loss: 0.4998 - val_acc: 0.8370
# Epoch 39/50
# 3000/3000 [==============================] - 1s 348us/step - loss: 0.2670 - acc: 0.9410 - val_loss: 0.4956 - val_acc: 0.8380
# Epoch 40/50
# 3000/3000 [==============================] - 1s 358us/step - loss: 0.2620 - acc: 0.9420 - val_loss: 0.4948 - val_acc: 0.8400
# Epoch 41/50
# 3000/3000 [==============================] - 1s 313us/step - loss: 0.2581 - acc: 0.9453 - val_loss: 0.4886 - val_acc: 0.8400
# Epoch 42/50
# 3000/3000 [==============================] - 1s 321us/step - loss: 0.2539 - acc: 0.9457 - val_loss: 0.4897 - val_acc: 0.8390
# Epoch 43/50
# 3000/3000 [==============================] - 1s 334us/step - loss: 0.2497 - acc: 0.9477 - val_loss: 0.4879 - val_acc: 0.8390
# Epoch 44/50
# 3000/3000 [==============================] - 1s 322us/step - loss: 0.2456 - acc: 0.9483 - val_loss: 0.4858 - val_acc: 0.8400
# Epoch 45/50
# 3000/3000 [==============================] - 1s 317us/step - loss: 0.2421 - acc: 0.9483 - val_loss: 0.4856 - val_acc: 0.8400
# Epoch 46/50
# 3000/3000 [==============================] - 1s 349us/step - loss: 0.2386 - acc: 0.9500 - val_loss: 0.4805 - val_acc: 0.8410
# Epoch 47/50
# 3000/3000 [==============================] - 1s 326us/step - loss: 0.2349 - acc: 0.9503 - val_loss: 0.4828 - val_acc: 0.8390
# Epoch 48/50
# 3000/3000 [==============================] - 1s 318us/step - loss: 0.2313 - acc: 0.9527 - val_loss: 0.4826 - val_acc: 0.8400
# Epoch 49/50
# 3000/3000 [==============================] - 1s 317us/step - loss: 0.2280 - acc: 0.9517 - val_loss: 0.4771 - val_acc: 0.8430
# Epoch 50/50
# 3000/3000 [==============================] - 1s 312us/step - loss: 0.2245 - acc: 0.9527 - val_loss: 0.4756 - val_acc: 0.8440

# %%
print(time.strftime("%H:%M:%S", time.gmtime(tt_bn_train)))
# Out:
# 00:00:50

# %%
import h5py
hdf5_file = h5py.File('../data/output_convnet/Inception/inception_bn_model.h5', mode='r')
print(list(hdf5_file))
# Out:
# ['dense_1', 'dense_2', 'global_average_pooling2d_1']

# %%
(loss, acc) = model.evaluate(val_data, val_labels, batch_size=batch_size, verbose=0)
print("acc: {0:.2f}% - loss: {1:f}".format(acc * 100, loss))
# Out:
# acc: 84.40% - loss: 0.475641

# %%
# historical_data.history acc and loss data over the epochs (train and validation)
import matplotlib.pyplot as plt

train_acc = historical_data.history['acc']
train_loss = historical_data.history['loss']

val_acc = historical_data.history['val_acc'] # validation
val_loss = historical_data.history['val_loss'] # validation

range_epochs = range(n_epochs)

fig = plt.figure(figsize=(20, 6))

fig.add_subplot(1,2,1)
plt.plot(range_epochs, train_acc, 'bo', label='Training acc')
plt.plot(range_epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

# plt.figure()
fig.add_subplot(1,2,2)
plt.plot(range_epochs, train_loss, 'bo', label='Training loss')
plt.plot(range_epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.savefig(os.path.join(PATH_TO_DF, "inception_bn_acc_loss.png"), bbox_inches='tight') # png 70kb vs jpg 135 kb
plt.show()

# %% [markdown]
# # fine tuning

# %%
from keras import applications
from keras.preprocessing.image import ImageDataGenerator
# from keras import optimizers
from keras.optimizers import SGD
from keras.models import Sequential
from keras.layers import Dropout, Flatten, Dense, Input

# %%
top_model_weights_path = '../data/output_convnet/Inception/inception_bn_model.h5'
batch_size = 5 # con 5 funciona con 16 es imposible probar con 10

# %%
# base model
input_tensor = Input(shape=(img_width,img_height,3)) # another way to shape the input
base_model = InceptionV3(weights='imagenet', include_top=False, input_tensor=input_tensor)

# %%
# top model
top_model = Sequential()
# model.add(Flatten(input_shape=train_data.shape[1:]))
top_model.add(GlobalAveragePooling2D(input_shape=train_data.shape[1:]))
top_model.add(Dense(1024, activation='relu'))
top_model.add(Dense(8, activation='softmax'))

# %%
# base model has its weights, now we load the weights on the top layer
top_model.load_weights("../data/output_convnet/Inception/inception_bn_model.h5")

# %%
# we join base and top it has to be updated to api2
model_total = Model(input= base_model.input, output= top_model(base_model.output))
# Out:
# /home/jon/anaconda3/envs/test/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("se...)`

# %%
# sequential is the top layer a complex one
for i, layer in enumerate(model_total.layers):
    print (i, layer.name, layer.output_shape)
# Out:
# 0 input_2 (None, 150, 150, 3)
# 1 conv2d_95 (None, 74, 74, 32)
# 2 batch_normalization_95 (None, 74, 74, 32)
# 3 activation_95 (None, 74, 74, 32)
# 4 conv2d_96 (None, 72, 72, 32)
# 5 batch_normalization_96 (None, 72, 72, 32)
# 6 activation_96 (None, 72, 72, 32)
# 7 conv2d_97 (None, 72, 72, 64)
# 8 batch_normalization_97 (None, 72, 72, 64)
# 9 activation_97 (None, 72, 72, 64)
# 10 max_pooling2d_5 (None, 35, 35, 64)
# 11 conv2d_98 (None, 35, 35, 80)
# 12 batch_normalization_98 (None, 35, 35, 80)
# 13 activation_98 (None, 35, 35, 80)
# 14 conv2d_99 (None, 33, 33, 192)
# 15 batch_normalization_99 (None, 33, 33, 192)
# 16 activation_99 (None, 33, 33, 192)
# 17 max_pooling2d_6 (None, 16, 16, 192)
# 18 conv2d_103 (None, 16, 16, 64)
# 19 batch_normalization_103 (None, 16, 16, 64)
# 20 activation_103 (None, 16, 16, 64)
# 21 conv2d_101 (None, 16, 16, 48)
# 22 conv2d_104 (None, 16, 16, 96)
# 23 batch_normalization_101 (None, 16, 16, 48)
# 24 batch_normalization_104 (None, 16, 16, 96)
# 25 activation_101 (None, 16, 16, 48)
# 26 activation_104 (None, 16, 16, 96)
# 27 average_pooling2d_10 (None, 16, 16, 192)
# 28 conv2d_100 (None, 16, 16, 64)
# 29 conv2d_102 (None, 16, 16, 64)
# 30 conv2d_105 (None, 16, 16, 96)
# 31 conv2d_106 (None, 16, 16, 32)
# 32 batch_normalization_100 (None, 16, 16, 64)
# 33 batch_normalization_102 (None, 16, 16, 64)
# 34 batch_normalization_105 (None, 16, 16, 96)
# 35 batch_normalization_106 (None, 16, 16, 32)
# 36 activation_100 (None, 16, 16, 64)
# 37 activation_102 (None, 16, 16, 64)
# 38 activation_105 (None, 16, 16, 96)
# 39 activation_106 (None, 16, 16, 32)
# 40 mixed0 (None, 16, 16, 256)
# 41 conv2d_110 (None, 16, 16, 64)
# 42 batch_normalization_110 (None, 16, 16, 64)
# 43 activation_110 (None, 16, 16, 64)
# 44 conv2d_108 (None, 16, 16, 48)
# 45 conv2d_111 (None, 16, 16, 96)
# 46 batch_normalization_108 (None, 16, 16, 48)
# 47 batch_normalization_111 (None, 16, 16, 96)
# 48 activation_108 (None, 16, 16, 48)
# 49 activation_111 (None, 16, 16, 96)
# 50 average_pooling2d_11 (None, 16, 16, 256)
# 51 conv2d_107 (None, 16, 16, 64)
# 52 conv2d_109 (None, 16, 16, 64)
# 53 conv2d_112 (None, 16, 16, 96)
# 54 conv2d_113 (None, 16, 16, 64)
# 55 batch_normalization_107 (None, 16, 16, 64)
# 56 batch_normalization_109 (None, 16, 16, 64)
# 57 batch_normalization_112 (None, 16, 16, 96)
# 58 batch_normalization_113 (None, 16, 16, 64)
# 59 activation_107 (None, 16, 16, 64)
# 60 activation_109 (None, 16, 16, 64)
# 61 activation_112 (None, 16, 16, 96)
# 62 activation_113 (None, 16, 16, 64)
# 63 mixed1 (None, 16, 16, 288)
# 64 conv2d_117 (None, 16, 16, 64)
# 65 batch_normalization_117 (None, 16, 16, 64)
# 66 activation_117 (None, 16, 16, 64)
# 67 conv2d_115 (None, 16, 16, 48)
# 68 conv2d_118 (None, 16, 16, 96)
# 69 batch_normalization_115 (None, 16, 16, 48)
# 70 batch_normalization_118 (None, 16, 16, 96)
# 71 activation_115 (None, 16, 16, 48)
# 72 activation_118 (None, 16, 16, 96)
# 73 average_pooling2d_12 (None, 16, 16, 288)
# 74 conv2d_114 (None, 16, 16, 64)
# 75 conv2d_116 (None, 16, 16, 64)
# 76 conv2d_119 (None, 16, 16, 96)
# 77 conv2d_120 (None, 16, 16, 64)
# 78 batch_normalization_114 (None, 16, 16, 64)
# 79 batch_normalization_116 (None, 16, 16, 64)
# 80 batch_normalization_119 (None, 16, 16, 96)
# 81 batch_normalization_120 (None, 16, 16, 64)
# 82 activation_114 (None, 16, 16, 64)
# 83 activation_116 (None, 16, 16, 64)
# 84 activation_119 (None, 16, 16, 96)
# 85 activation_120 (None, 16, 16, 64)
# 86 mixed2 (None, 16, 16, 288)
# 87 conv2d_122 (None, 16, 16, 64)
# 88 batch_normalization_122 (None, 16, 16, 64)
# 89 activation_122 (None, 16, 16, 64)
# 90 conv2d_123 (None, 16, 16, 96)
# 91 batch_normalization_123 (None, 16, 16, 96)
# 92 activation_123 (None, 16, 16, 96)
# 93 conv2d_121 (None, 7, 7, 384)
# 94 conv2d_124 (None, 7, 7, 96)
# 95 batch_normalization_121 (None, 7, 7, 384)
# 96 batch_normalization_124 (None, 7, 7, 96)
# 97 activation_121 (None, 7, 7, 384)
# 98 activation_124 (None, 7, 7, 96)
# 99 max_pooling2d_7 (None, 7, 7, 288)
# 100 mixed3 (None, 7, 7, 768)
# 101 conv2d_129 (None, 7, 7, 128)
# 102 batch_normalization_129 (None, 7, 7, 128)
# 103 activation_129 (None, 7, 7, 128)
# 104 conv2d_130 (None, 7, 7, 128)
# 105 batch_normalization_130 (None, 7, 7, 128)
# 106 activation_130 (None, 7, 7, 128)
# 107 conv2d_126 (None, 7, 7, 128)
# 108 conv2d_131 (None, 7, 7, 128)
# 109 batch_normalization_126 (None, 7, 7, 128)
# 110 batch_normalization_131 (None, 7, 7, 128)
# 111 activation_126 (None, 7, 7, 128)
# 112 activation_131 (None, 7, 7, 128)
# 113 conv2d_127 (None, 7, 7, 128)
# 114 conv2d_132 (None, 7, 7, 128)
# 115 batch_normalization_127 (None, 7, 7, 128)
# 116 batch_normalization_132 (None, 7, 7, 128)
# 117 activation_127 (None, 7, 7, 128)
# 118 activation_132 (None, 7, 7, 128)
# 119 average_pooling2d_13 (None, 7, 7, 768)
# 120 conv2d_125 (None, 7, 7, 192)
# 121 conv2d_128 (None, 7, 7, 192)
# 122 conv2d_133 (None, 7, 7, 192)
# 123 conv2d_134 (None, 7, 7, 192)
# 124 batch_normalization_125 (None, 7, 7, 192)
# 125 batch_normalization_128 (None, 7, 7, 192)
# 126 batch_normalization_133 (None, 7, 7, 192)
# 127 batch_normalization_134 (None, 7, 7, 192)
# 128 activation_125 (None, 7, 7, 192)
# 129 activation_128 (None, 7, 7, 192)
# 130 activation_133 (None, 7, 7, 192)
# 131 activation_134 (None, 7, 7, 192)
# 132 mixed4 (None, 7, 7, 768)
# 133 conv2d_139 (None, 7, 7, 160)
# 134 batch_normalization_139 (None, 7, 7, 160)
# 135 activation_139 (None, 7, 7, 160)
# 136 conv2d_140 (None, 7, 7, 160)
# 137 batch_normalization_140 (None, 7, 7, 160)
# 138 activation_140 (None, 7, 7, 160)
# 139 conv2d_136 (None, 7, 7, 160)
# 140 conv2d_141 (None, 7, 7, 160)
# 141 batch_normalization_136 (None, 7, 7, 160)
# 142 batch_normalization_141 (None, 7, 7, 160)
# 143 activation_136 (None, 7, 7, 160)
# 144 activation_141 (None, 7, 7, 160)
# 145 conv2d_137 (None, 7, 7, 160)
# 146 conv2d_142 (None, 7, 7, 160)
# 147 batch_normalization_137 (None, 7, 7, 160)
# 148 batch_normalization_142 (None, 7, 7, 160)
# 149 activation_137 (None, 7, 7, 160)
# 150 activation_142 (None, 7, 7, 160)
# 151 average_pooling2d_14 (None, 7, 7, 768)
# 152 conv2d_135 (None, 7, 7, 192)
# 153 conv2d_138 (None, 7, 7, 192)
# 154 conv2d_143 (None, 7, 7, 192)
# 155 conv2d_144 (None, 7, 7, 192)
# 156 batch_normalization_135 (None, 7, 7, 192)
# 157 batch_normalization_138 (None, 7, 7, 192)
# 158 batch_normalization_143 (None, 7, 7, 192)
# 159 batch_normalization_144 (None, 7, 7, 192)
# 160 activation_135 (None, 7, 7, 192)
# 161 activation_138 (None, 7, 7, 192)
# 162 activation_143 (None, 7, 7, 192)
# 163 activation_144 (None, 7, 7, 192)
# 164 mixed5 (None, 7, 7, 768)
# 165 conv2d_149 (None, 7, 7, 160)
# 166 batch_normalization_149 (None, 7, 7, 160)
# 167 activation_149 (None, 7, 7, 160)
# 168 conv2d_150 (None, 7, 7, 160)
# 169 batch_normalization_150 (None, 7, 7, 160)
# 170 activation_150 (None, 7, 7, 160)
# 171 conv2d_146 (None, 7, 7, 160)
# 172 conv2d_151 (None, 7, 7, 160)
# 173 batch_normalization_146 (None, 7, 7, 160)
# 174 batch_normalization_151 (None, 7, 7, 160)
# 175 activation_146 (None, 7, 7, 160)
# 176 activation_151 (None, 7, 7, 160)
# 177 conv2d_147 (None, 7, 7, 160)
# 178 conv2d_152 (None, 7, 7, 160)
# 179 batch_normalization_147 (None, 7, 7, 160)
# 180 batch_normalization_152 (None, 7, 7, 160)
# 181 activation_147 (None, 7, 7, 160)
# 182 activation_152 (None, 7, 7, 160)
# 183 average_pooling2d_15 (None, 7, 7, 768)
# 184 conv2d_145 (None, 7, 7, 192)
# 185 conv2d_148 (None, 7, 7, 192)
# 186 conv2d_153 (None, 7, 7, 192)
# 187 conv2d_154 (None, 7, 7, 192)
# 188 batch_normalization_145 (None, 7, 7, 192)
# 189 batch_normalization_148 (None, 7, 7, 192)
# 190 batch_normalization_153 (None, 7, 7, 192)
# 191 batch_normalization_154 (None, 7, 7, 192)
# 192 activation_145 (None, 7, 7, 192)
# 193 activation_148 (None, 7, 7, 192)
# 194 activation_153 (None, 7, 7, 192)
# 195 activation_154 (None, 7, 7, 192)
# 196 mixed6 (None, 7, 7, 768)
# 197 conv2d_159 (None, 7, 7, 192)
# 198 batch_normalization_159 (None, 7, 7, 192)
# 199 activation_159 (None, 7, 7, 192)
# 200 conv2d_160 (None, 7, 7, 192)
# 201 batch_normalization_160 (None, 7, 7, 192)
# 202 activation_160 (None, 7, 7, 192)
# 203 conv2d_156 (None, 7, 7, 192)
# 204 conv2d_161 (None, 7, 7, 192)
# 205 batch_normalization_156 (None, 7, 7, 192)
# 206 batch_normalization_161 (None, 7, 7, 192)
# 207 activation_156 (None, 7, 7, 192)
# 208 activation_161 (None, 7, 7, 192)
# 209 conv2d_157 (None, 7, 7, 192)
# 210 conv2d_162 (None, 7, 7, 192)
# 211 batch_normalization_157 (None, 7, 7, 192)
# 212 batch_normalization_162 (None, 7, 7, 192)
# 213 activation_157 (None, 7, 7, 192)
# 214 activation_162 (None, 7, 7, 192)
# 215 average_pooling2d_16 (None, 7, 7, 768)
# 216 conv2d_155 (None, 7, 7, 192)
# 217 conv2d_158 (None, 7, 7, 192)
# 218 conv2d_163 (None, 7, 7, 192)
# 219 conv2d_164 (None, 7, 7, 192)
# 220 batch_normalization_155 (None, 7, 7, 192)
# 221 batch_normalization_158 (None, 7, 7, 192)
# 222 batch_normalization_163 (None, 7, 7, 192)
# 223 batch_normalization_164 (None, 7, 7, 192)
# 224 activation_155 (None, 7, 7, 192)
# 225 activation_158 (None, 7, 7, 192)
# 226 activation_163 (None, 7, 7, 192)
# 227 activation_164 (None, 7, 7, 192)
# 228 mixed7 (None, 7, 7, 768)
# 229 conv2d_167 (None, 7, 7, 192)
# 230 batch_normalization_167 (None, 7, 7, 192)
# 231 activation_167 (None, 7, 7, 192)
# 232 conv2d_168 (None, 7, 7, 192)
# 233 batch_normalization_168 (None, 7, 7, 192)
# 234 activation_168 (None, 7, 7, 192)
# 235 conv2d_165 (None, 7, 7, 192)
# 236 conv2d_169 (None, 7, 7, 192)
# 237 batch_normalization_165 (None, 7, 7, 192)
# 238 batch_normalization_169 (None, 7, 7, 192)
# 239 activation_165 (None, 7, 7, 192)
# 240 activation_169 (None, 7, 7, 192)
# 241 conv2d_166 (None, 3, 3, 320)
# 242 conv2d_170 (None, 3, 3, 192)
# 243 batch_normalization_166 (None, 3, 3, 320)
# 244 batch_normalization_170 (None, 3, 3, 192)
# 245 activation_166 (None, 3, 3, 320)
# 246 activation_170 (None, 3, 3, 192)
# 247 max_pooling2d_8 (None, 3, 3, 768)
# 248 mixed8 (None, 3, 3, 1280)
# 249 conv2d_175 (None, 3, 3, 448)
# 250 batch_normalization_175 (None, 3, 3, 448)
# 251 activation_175 (None, 3, 3, 448)
# 252 conv2d_172 (None, 3, 3, 384)
# 253 conv2d_176 (None, 3, 3, 384)
# 254 batch_normalization_172 (None, 3, 3, 384)
# 255 batch_normalization_176 (None, 3, 3, 384)
# 256 activation_172 (None, 3, 3, 384)
# 257 activation_176 (None, 3, 3, 384)
# 258 conv2d_173 (None, 3, 3, 384)
# 259 conv2d_174 (None, 3, 3, 384)
# 260 conv2d_177 (None, 3, 3, 384)
# 261 conv2d_178 (None, 3, 3, 384)
# 262 average_pooling2d_17 (None, 3, 3, 1280)
# 263 conv2d_171 (None, 3, 3, 320)
# 264 batch_normalization_173 (None, 3, 3, 384)
# 265 batch_normalization_174 (None, 3, 3, 384)
# 266 batch_normalization_177 (None, 3, 3, 384)
# 267 batch_normalization_178 (None, 3, 3, 384)
# 268 conv2d_179 (None, 3, 3, 192)
# 269 batch_normalization_171 (None, 3, 3, 320)
# 270 activation_173 (None, 3, 3, 384)
# 271 activation_174 (None, 3, 3, 384)
# 272 activation_177 (None, 3, 3, 384)
# 273 activation_178 (None, 3, 3, 384)
# 274 batch_normalization_179 (None, 3, 3, 192)
# 275 activation_171 (None, 3, 3, 320)
# 276 mixed9_0 (None, 3, 3, 768)
# 277 concatenate_3 (None, 3, 3, 768)
# 278 activation_179 (None, 3, 3, 192)
# 279 mixed9 (None, 3, 3, 2048)
# 280 conv2d_184 (None, 3, 3, 448)
# 281 batch_normalization_184 (None, 3, 3, 448)
# 282 activation_184 (None, 3, 3, 448)
# 283 conv2d_181 (None, 3, 3, 384)
# 284 conv2d_185 (None, 3, 3, 384)
# 285 batch_normalization_181 (None, 3, 3, 384)
# 286 batch_normalization_185 (None, 3, 3, 384)
# 287 activation_181 (None, 3, 3, 384)
# 288 activation_185 (None, 3, 3, 384)
# 289 conv2d_182 (None, 3, 3, 384)
# 290 conv2d_183 (None, 3, 3, 384)
# 291 conv2d_186 (None, 3, 3, 384)
# 292 conv2d_187 (None, 3, 3, 384)
# 293 average_pooling2d_18 (None, 3, 3, 2048)
# 294 conv2d_180 (None, 3, 3, 320)
# 295 batch_normalization_182 (None, 3, 3, 384)
# 296 batch_normalization_183 (None, 3, 3, 384)
# 297 batch_normalization_186 (None, 3, 3, 384)
# 298 batch_normalization_187 (None, 3, 3, 384)
# 299 conv2d_188 (None, 3, 3, 192)
# 300 batch_normalization_180 (None, 3, 3, 320)
# 301 activation_182 (None, 3, 3, 384)
# 302 activation_183 (None, 3, 3, 384)
# 303 activation_186 (None, 3, 3, 384)
# 304 activation_187 (None, 3, 3, 384)
# 305 batch_normalization_188 (None, 3, 3, 192)
# 306 activation_180 (None, 3, 3, 320)
# 307 mixed9_1 (None, 3, 3, 768)
# 308 concatenate_4 (None, 3, 3, 768)
# 309 activation_188 (None, 3, 3, 192)
# 310 mixed10 (None, 3, 3, 2048)
# 311 sequential_2 (None, 8)

# %%
for i, layer in enumerate(model_total.layers):
    if layer.trainable:
        print("layer {0:d}, {1:s} is trainable".format(i, layer.name))
    else:
        print("layer {0:d}, {1:s} is freezed".format(i, layer.name))
# Out:
# layer 0, input_2 is freezed
# layer 1, conv2d_95 is trainable
# layer 2, batch_normalization_95 is trainable
# layer 3, activation_95 is trainable
# layer 4, conv2d_96 is trainable
# layer 5, batch_normalization_96 is trainable
# layer 6, activation_96 is trainable
# layer 7, conv2d_97 is trainable
# layer 8, batch_normalization_97 is trainable
# layer 9, activation_97 is trainable
# layer 10, max_pooling2d_5 is trainable
# layer 11, conv2d_98 is trainable
# layer 12, batch_normalization_98 is trainable
# layer 13, activation_98 is trainable
# layer 14, conv2d_99 is trainable
# layer 15, batch_normalization_99 is trainable
# layer 16, activation_99 is trainable
# layer 17, max_pooling2d_6 is trainable
# layer 18, conv2d_103 is trainable
# layer 19, batch_normalization_103 is trainable
# layer 20, activation_103 is trainable
# layer 21, conv2d_101 is trainable
# layer 22, conv2d_104 is trainable
# layer 23, batch_normalization_101 is trainable
# layer 24, batch_normalization_104 is trainable
# layer 25, activation_101 is trainable
# layer 26, activation_104 is trainable
# layer 27, average_pooling2d_10 is trainable
# layer 28, conv2d_100 is trainable
# layer 29, conv2d_102 is trainable
# layer 30, conv2d_105 is trainable
# layer 31, conv2d_106 is trainable
# layer 32, batch_normalization_100 is trainable
# layer 33, batch_normalization_102 is trainable
# layer 34, batch_normalization_105 is trainable
# layer 35, batch_normalization_106 is trainable
# layer 36, activation_100 is trainable
# layer 37, activation_102 is trainable
# layer 38, activation_105 is trainable
# layer 39, activation_106 is trainable
# layer 40, mixed0 is trainable
# layer 41, conv2d_110 is trainable
# layer 42, batch_normalization_110 is trainable
# layer 43, activation_110 is trainable
# layer 44, conv2d_108 is trainable
# layer 45, conv2d_111 is trainable
# layer 46, batch_normalization_108 is trainable
# layer 47, batch_normalization_111 is trainable
# layer 48, activation_108 is trainable
# layer 49, activation_111 is trainable
# layer 50, average_pooling2d_11 is trainable
# layer 51, conv2d_107 is trainable
# layer 52, conv2d_109 is trainable
# layer 53, conv2d_112 is trainable
# layer 54, conv2d_113 is trainable
# layer 55, batch_normalization_107 is trainable
# layer 56, batch_normalization_109 is trainable
# layer 57, batch_normalization_112 is trainable
# layer 58, batch_normalization_113 is trainable
# layer 59, activation_107 is trainable
# layer 60, activation_109 is trainable
# layer 61, activation_112 is trainable
# layer 62, activation_113 is trainable
# layer 63, mixed1 is trainable
# layer 64, conv2d_117 is trainable
# layer 65, batch_normalization_117 is trainable
# layer 66, activation_117 is trainable
# layer 67, conv2d_115 is trainable
# layer 68, conv2d_118 is trainable
# layer 69, batch_normalization_115 is trainable
# layer 70, batch_normalization_118 is trainable
# layer 71, activation_115 is trainable
# layer 72, activation_118 is trainable
# layer 73, average_pooling2d_12 is trainable
# layer 74, conv2d_114 is trainable
# layer 75, conv2d_116 is trainable
# layer 76, conv2d_119 is trainable
# layer 77, conv2d_120 is trainable
# layer 78, batch_normalization_114 is trainable
# layer 79, batch_normalization_116 is trainable
# layer 80, batch_normalization_119 is trainable
# layer 81, batch_normalization_120 is trainable
# layer 82, activation_114 is trainable
# layer 83, activation_116 is trainable
# layer 84, activation_119 is trainable
# layer 85, activation_120 is trainable
# layer 86, mixed2 is trainable
# layer 87, conv2d_122 is trainable
# layer 88, batch_normalization_122 is trainable
# layer 89, activation_122 is trainable
# layer 90, conv2d_123 is trainable
# layer 91, batch_normalization_123 is trainable
# layer 92, activation_123 is trainable
# layer 93, conv2d_121 is trainable
# layer 94, conv2d_124 is trainable
# layer 95, batch_normalization_121 is trainable
# layer 96, batch_normalization_124 is trainable
# layer 97, activation_121 is trainable
# layer 98, activation_124 is trainable
# layer 99, max_pooling2d_7 is trainable
# layer 100, mixed3 is trainable
# layer 101, conv2d_129 is trainable
# layer 102, batch_normalization_129 is trainable
# layer 103, activation_129 is trainable
# layer 104, conv2d_130 is trainable
# layer 105, batch_normalization_130 is trainable
# layer 106, activation_130 is trainable
# layer 107, conv2d_126 is trainable
# layer 108, conv2d_131 is trainable
# layer 109, batch_normalization_126 is trainable
# layer 110, batch_normalization_131 is trainable
# layer 111, activation_126 is trainable
# layer 112, activation_131 is trainable
# layer 113, conv2d_127 is trainable
# layer 114, conv2d_132 is trainable
# layer 115, batch_normalization_127 is trainable
# layer 116, batch_normalization_132 is trainable
# layer 117, activation_127 is trainable
# layer 118, activation_132 is trainable
# layer 119, average_pooling2d_13 is trainable
# layer 120, conv2d_125 is trainable
# layer 121, conv2d_128 is trainable
# layer 122, conv2d_133 is trainable
# layer 123, conv2d_134 is trainable
# layer 124, batch_normalization_125 is trainable
# layer 125, batch_normalization_128 is trainable
# layer 126, batch_normalization_133 is trainable
# layer 127, batch_normalization_134 is trainable
# layer 128, activation_125 is trainable
# layer 129, activation_128 is trainable
# layer 130, activation_133 is trainable
# layer 131, activation_134 is trainable
# layer 132, mixed4 is trainable
# layer 133, conv2d_139 is trainable
# layer 134, batch_normalization_139 is trainable
# layer 135, activation_139 is trainable
# layer 136, conv2d_140 is trainable
# layer 137, batch_normalization_140 is trainable
# layer 138, activation_140 is trainable
# layer 139, conv2d_136 is trainable
# layer 140, conv2d_141 is trainable
# layer 141, batch_normalization_136 is trainable
# layer 142, batch_normalization_141 is trainable
# layer 143, activation_136 is trainable
# layer 144, activation_141 is trainable
# layer 145, conv2d_137 is trainable
# layer 146, conv2d_142 is trainable
# layer 147, batch_normalization_137 is trainable
# layer 148, batch_normalization_142 is trainable
# layer 149, activation_137 is trainable
# layer 150, activation_142 is trainable
# layer 151, average_pooling2d_14 is trainable
# layer 152, conv2d_135 is trainable
# layer 153, conv2d_138 is trainable
# layer 154, conv2d_143 is trainable
# layer 155, conv2d_144 is trainable
# layer 156, batch_normalization_135 is trainable
# layer 157, batch_normalization_138 is trainable
# layer 158, batch_normalization_143 is trainable
# layer 159, batch_normalization_144 is trainable
# layer 160, activation_135 is trainable
# layer 161, activation_138 is trainable
# layer 162, activation_143 is trainable
# layer 163, activation_144 is trainable
# layer 164, mixed5 is trainable
# layer 165, conv2d_149 is trainable
# layer 166, batch_normalization_149 is trainable
# layer 167, activation_149 is trainable
# layer 168, conv2d_150 is trainable
# layer 169, batch_normalization_150 is trainable
# layer 170, activation_150 is trainable
# layer 171, conv2d_146 is trainable
# layer 172, conv2d_151 is trainable
# layer 173, batch_normalization_146 is trainable
# layer 174, batch_normalization_151 is trainable
# layer 175, activation_146 is trainable
# layer 176, activation_151 is trainable
# layer 177, conv2d_147 is trainable
# layer 178, conv2d_152 is trainable
# layer 179, batch_normalization_147 is trainable
# layer 180, batch_normalization_152 is trainable
# layer 181, activation_147 is trainable
# layer 182, activation_152 is trainable
# layer 183, average_pooling2d_15 is trainable
# layer 184, conv2d_145 is trainable
# layer 185, conv2d_148 is trainable
# layer 186, conv2d_153 is trainable
# layer 187, conv2d_154 is trainable
# layer 188, batch_normalization_145 is trainable
# layer 189, batch_normalization_148 is trainable
# layer 190, batch_normalization_153 is trainable
# layer 191, batch_normalization_154 is trainable
# layer 192, activation_145 is trainable
# layer 193, activation_148 is trainable
# layer 194, activation_153 is trainable
# layer 195, activation_154 is trainable
# layer 196, mixed6 is trainable
# layer 197, conv2d_159 is trainable
# layer 198, batch_normalization_159 is trainable
# layer 199, activation_159 is trainable
# layer 200, conv2d_160 is trainable
# layer 201, batch_normalization_160 is trainable
# layer 202, activation_160 is trainable
# layer 203, conv2d_156 is trainable
# layer 204, conv2d_161 is trainable
# layer 205, batch_normalization_156 is trainable
# layer 206, batch_normalization_161 is trainable
# layer 207, activation_156 is trainable
# layer 208, activation_161 is trainable
# layer 209, conv2d_157 is trainable
# layer 210, conv2d_162 is trainable
# layer 211, batch_normalization_157 is trainable
# layer 212, batch_normalization_162 is trainable
# layer 213, activation_157 is trainable
# layer 214, activation_162 is trainable
# layer 215, average_pooling2d_16 is trainable
# layer 216, conv2d_155 is trainable
# layer 217, conv2d_158 is trainable
# layer 218, conv2d_163 is trainable
# layer 219, conv2d_164 is trainable
# layer 220, batch_normalization_155 is trainable
# layer 221, batch_normalization_158 is trainable
# layer 222, batch_normalization_163 is trainable
# layer 223, batch_normalization_164 is trainable
# layer 224, activation_155 is trainable
# layer 225, activation_158 is trainable
# layer 226, activation_163 is trainable
# layer 227, activation_164 is trainable
# layer 228, mixed7 is trainable
# layer 229, conv2d_167 is trainable
# layer 230, batch_normalization_167 is trainable
# layer 231, activation_167 is trainable
# layer 232, conv2d_168 is trainable
# layer 233, batch_normalization_168 is trainable
# layer 234, activation_168 is trainable
# layer 235, conv2d_165 is trainable
# layer 236, conv2d_169 is trainable
# layer 237, batch_normalization_165 is trainable
# layer 238, batch_normalization_169 is trainable
# layer 239, activation_165 is trainable
# layer 240, activation_169 is trainable
# layer 241, conv2d_166 is trainable
# layer 242, conv2d_170 is trainable
# layer 243, batch_normalization_166 is trainable
# layer 244, batch_normalization_170 is trainable
# layer 245, activation_166 is trainable
# layer 246, activation_170 is trainable
# layer 247, max_pooling2d_8 is trainable
# layer 248, mixed8 is trainable
# layer 249, conv2d_175 is trainable
# layer 250, batch_normalization_175 is trainable
# layer 251, activation_175 is trainable
# layer 252, conv2d_172 is trainable
# layer 253, conv2d_176 is trainable
# layer 254, batch_normalization_172 is trainable
# layer 255, batch_normalization_176 is trainable
# layer 256, activation_172 is trainable
# layer 257, activation_176 is trainable
# layer 258, conv2d_173 is trainable
# layer 259, conv2d_174 is trainable
# layer 260, conv2d_177 is trainable
# layer 261, conv2d_178 is trainable
# layer 262, average_pooling2d_17 is trainable
# layer 263, conv2d_171 is trainable
# layer 264, batch_normalization_173 is trainable
# layer 265, batch_normalization_174 is trainable
# layer 266, batch_normalization_177 is trainable
# layer 267, batch_normalization_178 is trainable
# layer 268, conv2d_179 is trainable
# layer 269, batch_normalization_171 is trainable
# layer 270, activation_173 is trainable
# layer 271, activation_174 is trainable
# layer 272, activation_177 is trainable
# layer 273, activation_178 is trainable
# layer 274, batch_normalization_179 is trainable
# layer 275, activation_171 is trainable
# layer 276, mixed9_0 is trainable
# layer 277, concatenate_3 is trainable
# layer 278, activation_179 is trainable
# layer 279, mixed9 is trainable
# layer 280, conv2d_184 is trainable
# layer 281, batch_normalization_184 is trainable
# layer 282, activation_184 is trainable
# layer 283, conv2d_181 is trainable
# layer 284, conv2d_185 is trainable
# layer 285, batch_normalization_181 is trainable
# layer 286, batch_normalization_185 is trainable
# layer 287, activation_181 is trainable
# layer 288, activation_185 is trainable
# layer 289, conv2d_182 is trainable
# layer 290, conv2d_183 is trainable
# layer 291, conv2d_186 is trainable
# layer 292, conv2d_187 is trainable
# layer 293, average_pooling2d_18 is trainable
# layer 294, conv2d_180 is trainable
# layer 295, batch_normalization_182 is trainable
# layer 296, batch_normalization_183 is trainable
# layer 297, batch_normalization_186 is trainable
# layer 298, batch_normalization_187 is trainable
# layer 299, conv2d_188 is trainable
# layer 300, batch_normalization_180 is trainable
# layer 301, activation_182 is trainable
# layer 302, activation_183 is trainable
# layer 303, activation_186 is trainable
# layer 304, activation_187 is trainable
# layer 305, batch_normalization_188 is trainable
# layer 306, activation_180 is trainable
# layer 307, mixed9_1 is trainable
# layer 308, concatenate_4 is trainable
# layer 309, activation_188 is trainable
# layer 310, mixed10 is trainable
# layer 311, sequential_2 is trainable

# %%
# freezing layers implies they will not update their weights over the training
# https://github.com/keras-team/keras/blob/master/keras/applications/inception_v3.py#L325
# tha's the key to the last conv layer
for layer in model_total.layers[:280]:
    layer.trainable = False
for layer in model_total.layers[280:]:
    layer.trainable = True

# %%
# check for updates
for i, layer in enumerate(model_total.layers):
    if layer.trainable:
        print("layer {0:d}, {1:s} is trainable".format(i, layer.name))
    else:
        print("layer {0:d}, {1:s} is freezed".format(i, layer.name))
# Out:
# layer 0, input_2 is freezed
# layer 1, conv2d_95 is freezed
# layer 2, batch_normalization_95 is freezed
# layer 3, activation_95 is freezed
# layer 4, conv2d_96 is freezed
# layer 5, batch_normalization_96 is freezed
# layer 6, activation_96 is freezed
# layer 7, conv2d_97 is freezed
# layer 8, batch_normalization_97 is freezed
# layer 9, activation_97 is freezed
# layer 10, max_pooling2d_5 is freezed
# layer 11, conv2d_98 is freezed
# layer 12, batch_normalization_98 is freezed
# layer 13, activation_98 is freezed
# layer 14, conv2d_99 is freezed
# layer 15, batch_normalization_99 is freezed
# layer 16, activation_99 is freezed
# layer 17, max_pooling2d_6 is freezed
# layer 18, conv2d_103 is freezed
# layer 19, batch_normalization_103 is freezed
# layer 20, activation_103 is freezed
# layer 21, conv2d_101 is freezed
# layer 22, conv2d_104 is freezed
# layer 23, batch_normalization_101 is freezed
# layer 24, batch_normalization_104 is freezed
# layer 25, activation_101 is freezed
# layer 26, activation_104 is freezed
# layer 27, average_pooling2d_10 is freezed
# layer 28, conv2d_100 is freezed
# layer 29, conv2d_102 is freezed
# layer 30, conv2d_105 is freezed
# layer 31, conv2d_106 is freezed
# layer 32, batch_normalization_100 is freezed
# layer 33, batch_normalization_102 is freezed
# layer 34, batch_normalization_105 is freezed
# layer 35, batch_normalization_106 is freezed
# layer 36, activation_100 is freezed
# layer 37, activation_102 is freezed
# layer 38, activation_105 is freezed
# layer 39, activation_106 is freezed
# layer 40, mixed0 is freezed
# layer 41, conv2d_110 is freezed
# layer 42, batch_normalization_110 is freezed
# layer 43, activation_110 is freezed
# layer 44, conv2d_108 is freezed
# layer 45, conv2d_111 is freezed
# layer 46, batch_normalization_108 is freezed
# layer 47, batch_normalization_111 is freezed
# layer 48, activation_108 is freezed
# layer 49, activation_111 is freezed
# layer 50, average_pooling2d_11 is freezed
# layer 51, conv2d_107 is freezed
# layer 52, conv2d_109 is freezed
# layer 53, conv2d_112 is freezed
# layer 54, conv2d_113 is freezed
# layer 55, batch_normalization_107 is freezed
# layer 56, batch_normalization_109 is freezed
# layer 57, batch_normalization_112 is freezed
# layer 58, batch_normalization_113 is freezed
# layer 59, activation_107 is freezed
# layer 60, activation_109 is freezed
# layer 61, activation_112 is freezed
# layer 62, activation_113 is freezed
# layer 63, mixed1 is freezed
# layer 64, conv2d_117 is freezed
# layer 65, batch_normalization_117 is freezed
# layer 66, activation_117 is freezed
# layer 67, conv2d_115 is freezed
# layer 68, conv2d_118 is freezed
# layer 69, batch_normalization_115 is freezed
# layer 70, batch_normalization_118 is freezed
# layer 71, activation_115 is freezed
# layer 72, activation_118 is freezed
# layer 73, average_pooling2d_12 is freezed
# layer 74, conv2d_114 is freezed
# layer 75, conv2d_116 is freezed
# layer 76, conv2d_119 is freezed
# layer 77, conv2d_120 is freezed
# layer 78, batch_normalization_114 is freezed
# layer 79, batch_normalization_116 is freezed
# layer 80, batch_normalization_119 is freezed
# layer 81, batch_normalization_120 is freezed
# layer 82, activation_114 is freezed
# layer 83, activation_116 is freezed
# layer 84, activation_119 is freezed
# layer 85, activation_120 is freezed
# layer 86, mixed2 is freezed
# layer 87, conv2d_122 is freezed
# layer 88, batch_normalization_122 is freezed
# layer 89, activation_122 is freezed
# layer 90, conv2d_123 is freezed
# layer 91, batch_normalization_123 is freezed
# layer 92, activation_123 is freezed
# layer 93, conv2d_121 is freezed
# layer 94, conv2d_124 is freezed
# layer 95, batch_normalization_121 is freezed
# layer 96, batch_normalization_124 is freezed
# layer 97, activation_121 is freezed
# layer 98, activation_124 is freezed
# layer 99, max_pooling2d_7 is freezed
# layer 100, mixed3 is freezed
# layer 101, conv2d_129 is freezed
# layer 102, batch_normalization_129 is freezed
# layer 103, activation_129 is freezed
# layer 104, conv2d_130 is freezed
# layer 105, batch_normalization_130 is freezed
# layer 106, activation_130 is freezed
# layer 107, conv2d_126 is freezed
# layer 108, conv2d_131 is freezed
# layer 109, batch_normalization_126 is freezed
# layer 110, batch_normalization_131 is freezed
# layer 111, activation_126 is freezed
# layer 112, activation_131 is freezed
# layer 113, conv2d_127 is freezed
# layer 114, conv2d_132 is freezed
# layer 115, batch_normalization_127 is freezed
# layer 116, batch_normalization_132 is freezed
# layer 117, activation_127 is freezed
# layer 118, activation_132 is freezed
# layer 119, average_pooling2d_13 is freezed
# layer 120, conv2d_125 is freezed
# layer 121, conv2d_128 is freezed
# layer 122, conv2d_133 is freezed
# layer 123, conv2d_134 is freezed
# layer 124, batch_normalization_125 is freezed
# layer 125, batch_normalization_128 is freezed
# layer 126, batch_normalization_133 is freezed
# layer 127, batch_normalization_134 is freezed
# layer 128, activation_125 is freezed
# layer 129, activation_128 is freezed
# layer 130, activation_133 is freezed
# layer 131, activation_134 is freezed
# layer 132, mixed4 is freezed
# layer 133, conv2d_139 is freezed
# layer 134, batch_normalization_139 is freezed
# layer 135, activation_139 is freezed
# layer 136, conv2d_140 is freezed
# layer 137, batch_normalization_140 is freezed
# layer 138, activation_140 is freezed
# layer 139, conv2d_136 is freezed
# layer 140, conv2d_141 is freezed
# layer 141, batch_normalization_136 is freezed
# layer 142, batch_normalization_141 is freezed
# layer 143, activation_136 is freezed
# layer 144, activation_141 is freezed
# layer 145, conv2d_137 is freezed
# layer 146, conv2d_142 is freezed
# layer 147, batch_normalization_137 is freezed
# layer 148, batch_normalization_142 is freezed
# layer 149, activation_137 is freezed
# layer 150, activation_142 is freezed
# layer 151, average_pooling2d_14 is freezed
# layer 152, conv2d_135 is freezed
# layer 153, conv2d_138 is freezed
# layer 154, conv2d_143 is freezed
# layer 155, conv2d_144 is freezed
# layer 156, batch_normalization_135 is freezed
# layer 157, batch_normalization_138 is freezed
# layer 158, batch_normalization_143 is freezed
# layer 159, batch_normalization_144 is freezed
# layer 160, activation_135 is freezed
# layer 161, activation_138 is freezed
# layer 162, activation_143 is freezed
# layer 163, activation_144 is freezed
# layer 164, mixed5 is freezed
# layer 165, conv2d_149 is freezed
# layer 166, batch_normalization_149 is freezed
# layer 167, activation_149 is freezed
# layer 168, conv2d_150 is freezed
# layer 169, batch_normalization_150 is freezed
# layer 170, activation_150 is freezed
# layer 171, conv2d_146 is freezed
# layer 172, conv2d_151 is freezed
# layer 173, batch_normalization_146 is freezed
# layer 174, batch_normalization_151 is freezed
# layer 175, activation_146 is freezed
# layer 176, activation_151 is freezed
# layer 177, conv2d_147 is freezed
# layer 178, conv2d_152 is freezed
# layer 179, batch_normalization_147 is freezed
# layer 180, batch_normalization_152 is freezed
# layer 181, activation_147 is freezed
# layer 182, activation_152 is freezed
# layer 183, average_pooling2d_15 is freezed
# layer 184, conv2d_145 is freezed
# layer 185, conv2d_148 is freezed
# layer 186, conv2d_153 is freezed
# layer 187, conv2d_154 is freezed
# layer 188, batch_normalization_145 is freezed
# layer 189, batch_normalization_148 is freezed
# layer 190, batch_normalization_153 is freezed
# layer 191, batch_normalization_154 is freezed
# layer 192, activation_145 is freezed
# layer 193, activation_148 is freezed
# layer 194, activation_153 is freezed
# layer 195, activation_154 is freezed
# layer 196, mixed6 is freezed
# layer 197, conv2d_159 is freezed
# layer 198, batch_normalization_159 is freezed
# layer 199, activation_159 is freezed
# layer 200, conv2d_160 is freezed
# layer 201, batch_normalization_160 is freezed
# layer 202, activation_160 is freezed
# layer 203, conv2d_156 is freezed
# layer 204, conv2d_161 is freezed
# layer 205, batch_normalization_156 is freezed
# layer 206, batch_normalization_161 is freezed
# layer 207, activation_156 is freezed
# layer 208, activation_161 is freezed
# layer 209, conv2d_157 is freezed
# layer 210, conv2d_162 is freezed
# layer 211, batch_normalization_157 is freezed
# layer 212, batch_normalization_162 is freezed
# layer 213, activation_157 is freezed
# layer 214, activation_162 is freezed
# layer 215, average_pooling2d_16 is freezed
# layer 216, conv2d_155 is freezed
# layer 217, conv2d_158 is freezed
# layer 218, conv2d_163 is freezed
# layer 219, conv2d_164 is freezed
# layer 220, batch_normalization_155 is freezed
# layer 221, batch_normalization_158 is freezed
# layer 222, batch_normalization_163 is freezed
# layer 223, batch_normalization_164 is freezed
# layer 224, activation_155 is freezed
# layer 225, activation_158 is freezed
# layer 226, activation_163 is freezed
# layer 227, activation_164 is freezed
# layer 228, mixed7 is freezed
# layer 229, conv2d_167 is freezed
# layer 230, batch_normalization_167 is freezed
# layer 231, activation_167 is freezed
# layer 232, conv2d_168 is freezed
# layer 233, batch_normalization_168 is freezed
# layer 234, activation_168 is freezed
# layer 235, conv2d_165 is freezed
# layer 236, conv2d_169 is freezed
# layer 237, batch_normalization_165 is freezed
# layer 238, batch_normalization_169 is freezed
# layer 239, activation_165 is freezed
# layer 240, activation_169 is freezed
# layer 241, conv2d_166 is freezed
# layer 242, conv2d_170 is freezed
# layer 243, batch_normalization_166 is freezed
# layer 244, batch_normalization_170 is freezed
# layer 245, activation_166 is freezed
# layer 246, activation_170 is freezed
# layer 247, max_pooling2d_8 is freezed
# layer 248, mixed8 is freezed
# layer 249, conv2d_175 is freezed
# layer 250, batch_normalization_175 is freezed
# layer 251, activation_175 is freezed
# layer 252, conv2d_172 is freezed
# layer 253, conv2d_176 is freezed
# layer 254, batch_normalization_172 is freezed
# layer 255, batch_normalization_176 is freezed
# layer 256, activation_172 is freezed
# layer 257, activation_176 is freezed
# layer 258, conv2d_173 is freezed
# layer 259, conv2d_174 is freezed
# layer 260, conv2d_177 is freezed
# layer 261, conv2d_178 is freezed
# layer 262, average_pooling2d_17 is freezed
# layer 263, conv2d_171 is freezed
# layer 264, batch_normalization_173 is freezed
# layer 265, batch_normalization_174 is freezed
# layer 266, batch_normalization_177 is freezed
# layer 267, batch_normalization_178 is freezed
# layer 268, conv2d_179 is freezed
# layer 269, batch_normalization_171 is freezed
# layer 270, activation_173 is freezed
# layer 271, activation_174 is freezed
# layer 272, activation_177 is freezed
# layer 273, activation_178 is freezed
# layer 274, batch_normalization_179 is freezed
# layer 275, activation_171 is freezed
# layer 276, mixed9_0 is freezed
# layer 277, concatenate_3 is freezed
# layer 278, activation_179 is freezed
# layer 279, mixed9 is freezed
# layer 280, conv2d_184 is trainable
# layer 281, batch_normalization_184 is trainable
# layer 282, activation_184 is trainable
# layer 283, conv2d_181 is trainable
# layer 284, conv2d_185 is trainable
# layer 285, batch_normalization_181 is trainable
# layer 286, batch_normalization_185 is trainable
# layer 287, activation_181 is trainable
# layer 288, activation_185 is trainable
# layer 289, conv2d_182 is trainable
# layer 290, conv2d_183 is trainable
# layer 291, conv2d_186 is trainable
# layer 292, conv2d_187 is trainable
# layer 293, average_pooling2d_18 is trainable
# layer 294, conv2d_180 is trainable
# layer 295, batch_normalization_182 is trainable
# layer 296, batch_normalization_183 is trainable
# layer 297, batch_normalization_186 is trainable
# layer 298, batch_normalization_187 is trainable
# layer 299, conv2d_188 is trainable
# layer 300, batch_normalization_180 is trainable
# layer 301, activation_182 is trainable
# layer 302, activation_183 is trainable
# layer 303, activation_186 is trainable
# layer 304, activation_187 is trainable
# layer 305, batch_normalization_188 is trainable
# layer 306, activation_180 is trainable
# layer 307, mixed9_1 is trainable
# layer 308, concatenate_4 is trainable
# layer 309, activation_188 is trainable
# layer 310, mixed10 is trainable
# layer 311, sequential_2 is trainable

# %%
model_total.compile(optimizer=SGD(lr=1e-4, momentum=0.9),
              loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# diff with bottleneck, we have to use data augmentation here
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical')

val_datagen = ImageDataGenerator(rescale=1. / 255) # not in the val data

val_generator = val_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical')
# Out:
# Found 3000 images belonging to 8 classes.
# Found 1000 images belonging to 8 classes.

# %%
n_epochs = 5 # just for testing purposes
'''
some cells are run based only in 5 epoch just for testing purposes
the real weights were calculated with 50 epochs and will be loaded ahead
'''
# Out:
# '\nsome cells are run based only in 5 epoch just for testing purposes\nthe real weights were calculated with 50 epochs and will be loaded ahead\n'

# %%
import time
# fine-tune the model

ti_ftuning = time.time()


historical_data = model_total.fit_generator(
    train_generator,
    samples_per_epoch=n_train_samples,
    epochs=n_epochs,
    verbose = 1,
    validation_data=val_generator,
    validation_steps=n_validation_samples)

tf_ftuning = time.time()
tt_ftuning = tf_ftuning - ti_ftuning
# Out:
# /home/jon/anaconda3/envs/test/lib/python3.6/site-packages/ipykernel_launcher.py:13: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras.pre..., epochs=5, verbose=1, validation_data=<keras.pre..., validation_steps=1000, steps_per_epoch=600)`
#   del sys.path[0]
# Epoch 1/5
# 600/600 [==============================] - 71s 119ms/step - loss: 1.2025 - acc: 0.5713 - val_loss: 2.0350 - val_acc: 0.6450
# Epoch 2/5
# 600/600 [==============================] - 67s 112ms/step - loss: 1.0119 - acc: 0.6503 - val_loss: 2.1163 - val_acc: 0.6520
# Epoch 3/5
# 600/600 [==============================] - 67s 112ms/step - loss: 0.9169 - acc: 0.6863 - val_loss: 2.3535 - val_acc: 0.6640
# Epoch 4/5
# 600/600 [==============================] - 67s 111ms/step - loss: 0.8666 - acc: 0.7083 - val_loss: 2.6319 - val_acc: 0.6460
# Epoch 5/5
# 600/600 [==============================] - 67s 111ms/step - loss: 0.8255 - acc: 0.7003 - val_loss: 2.5382 - val_acc: 0.6790

# %%
print(time.strftime("%H:%M:%S", time.gmtime(tt_ftuning)))
# Out:
# 00:05:40

# %%
model_total.save_weights('../data/output_convnet/Inception/inception_ft_testing_model.h5') # testing
# model_total.save_weights('../data/output_convnet/Inception/inception_ft_model.h5')

# %%
steps = int(math.ceil(n_validation_samples / batch_size))
(loss, acc) = model_total.evaluate_generator(val_generator, steps=steps)
print("acc: {0:.2f}% - loss: {1:f}".format(acc * 100, loss))
# Out:
# acc: 67.90% - loss: 2.538239

# %%
train_acc = historical_data.history['acc']
train_loss = historical_data.history['loss']

val_acc = historical_data.history['val_acc'] # validation
val_loss = historical_data.history['val_loss'] # validation

print("train acc mean: {0:.2f} * train loss mean: {1:.2f}".format(np.average(train_acc),np.average(train_loss)))
print("validation acc mean: {0:.2f} * validation loss mean: {1:.2f}".format(np.average(val_acc),np.average(val_loss)))
# Out:
# train acc mean: 0.66 * train loss mean: 0.96
# validation acc mean: 0.66 * validation loss mean: 2.33

# %%
# historical_data.history acc and loss data over the epochs (train and validation)

range_epochs = range(n_epochs)

fig = plt.figure(figsize=(20, 6))

fig.add_subplot(1,2,1)
plt.plot(range_epochs, train_acc, 'bo', label='Training acc')
plt.plot(range_epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

# plt.figure()
fig.add_subplot(1,2,2)
plt.plot(range_epochs, train_loss, 'bo', label='Training loss')
plt.plot(range_epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.savefig(os.path.join(PATH_TO_DF, "VGG19_ft_testing_acc_loss.png"), bbox_inches='tight')
# plt.savefig(os.path.join(PATH_TO_DF, "VGG19_ft_acc_loss.png"), bbox_inches='tight')
plt.show()

# %%
# import h5py

# hdf5_file = h5py.File('../data/output_convnet/VGG19/VGG19_ft_model.h5', mode='r')

model_base = InceptionV3(weights='imagenet', include_top=False, input_tensor=input_tensor)  

# top model
top_model = Sequential()
# model.add(Flatten(input_shape=train_data.shape[1:]))
top_model.add(GlobalAveragePooling2D(input_shape=train_data.shape[1:]))
top_model.add(Dense(1024, activation='relu'))
top_model.add(Dense(8, activation='softmax'))

model_total = Model(input= base_model.input, output= top_model(base_model.output))

# loading the weights trained before
model_total.load_weights("../data/output_convnet/Inception/inception_ft_model.h5")

model_total.compile(optimizer=SGD(lr=1e-4, momentum=0.9),
              loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /home/jon/anaconda3/envs/test/lib/python3.6/site-packages/ipykernel_launcher.py:14: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("se...)`

# %%
test_convnet = ImageDataGenerator(rescale=1. / 255)

test_generator = test_convnet.flow_from_directory(
    test_data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    shuffle =False,
    class_mode='categorical')
# Out:
# Found 1000 images belonging to 8 classes.

# %%
steps = int(math.ceil(n_test_samples / batch_size))

(loss, acc) = model_total.evaluate_generator(test_generator, steps=steps)

print("acc: {0:.2f}% - loss: {1:f}".format(acc * 100, loss))
# Out:
# acc: 68.20% - loss: 2.811705

# %%
predictions = model_total.predict_generator(test_generator, steps = steps)

# %%
from sklearn.metrics import confusion_matrix

PATH_TO_IMG = "../data/input_dataset"

prediction_list = []
real_label_list = []

cat_dict = test_generator.class_indices # the key attribute
inverse_coding = {value: key for key, value in cat_dict.items()} # dict of categories

for label in test_generator.classes:
    real_label_list.append(inverse_coding[label])
    
for prediction in predictions:
    prediction_list.append(inverse_coding[np.argmax(prediction)])

# in order to get the confusion matrix
class_names = sorted([folder for folder in os.listdir(PATH_TO_IMG)
                  if os.path.isdir(os.path.join(PATH_TO_IMG, folder))])
prediction_list_arr = np.array(prediction_list) 
real_label_list_arr = np.array(real_label_list)

inception_cm_ft = confusion_matrix(real_label_list_arr,prediction_list_arr)

# %%
# reference http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
import itertools
import matplotlib.pyplot as plt

def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label',size=20)
    plt.xlabel('Predicted label',size=20)

# %%
fig = plt.figure(figsize=(20, 6))


fig.add_subplot(1,2,1)
plot_confusion_matrix(inception_cm_ft, classes=class_names,
                      title='Confusion matrix, without normalization')

fig.add_subplot(1,2,2)
plot_confusion_matrix(inception_cm_ft, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.savefig(os.path.join(PATH_TO_DF, "inception_ft_test.png"), bbox_inches='tight') # png 70kb vs jpg 135 kb

plt.show()
