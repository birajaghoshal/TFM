# %%
from keras.applications.inception_v3 import InceptionV3
from keras.preprocessing import image
from keras.models import Model
from keras.layers import Dense, GlobalAveragePooling2D
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %%
from keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from keras.models import Sequential
from keras.layers import Dropout, Flatten, Dense
from keras import applications
from keras.optimizers import SGD
from keras.utils.np_utils import to_categorical

import matplotlib.pyplot as plt
import numpy as np
import math

# %%
img_width = 150
img_height = 150

epochs = 50
batch_size = 16

train_data_dir = "train"  
validation_data_dir = "validation"
test_data_dir = "test"

nb_train_samples = 3000
nb_validation_samples = 1000

# %%
import time

ti_bn_features = time.time()

model = InceptionV3(include_top=False, weights='imagenet')

datagen = ImageDataGenerator(rescale=1. / 255)

'''
https://github.com/keras-team/keras/blob/master/keras/preprocessing/image.py#L1002
if PIL version 1.1.3 interpolation = 'lanczos'
else interpolation = 'bicubic' 
''' 

generator = datagen.flow_from_directory(
    train_data_dir,
    target_size = (img_width, img_height),
    batch_size = batch_size,
    class_mode = None,
    shuffle = False)

nb_train_samples = len(generator.filenames)  
num_classes = len(generator.class_indices)

predict_size_train = int(math.ceil(nb_train_samples / batch_size)) 

bnfeatures_train = model.predict_generator(
    generator, predict_size_train)

np.save('../data/output_convnet/inception_bnfeatures_train.npy', bnfeatures_train)


generator = datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode=None,
    shuffle=False)

nb_validation_samples = len(generator.filenames)
predict_size_validation = int(math.ceil(nb_validation_samples / batch_size))  
   
bnfeatures_val = model.predict_generator(  
     generator, predict_size_validation)

np.save('../data/output_convnet/inception_bnfeatures_val.npy', bnfeatures_val)


tf_bn_features = time.time()    
tt_bn_features = tf_bn_features - ti_bn_features
print(time.strftime("%H:%M:%S", time.gmtime(tt_bn_features)))
# Out:
# Found 3000 images belonging to 8 classes.
# Found 1000 images belonging to 8 classes.
# 00:00:28

# %%
import os

ti_bn_train = time.time()

datagen_top = ImageDataGenerator(rescale=1./255)  

generator_top = datagen_top.flow_from_directory(
    train_data_dir,  
    target_size=(img_width, img_height),  
    batch_size=batch_size,  
    class_mode='categorical',  
    shuffle=False,
    interpolation = 'lanczos')  

nb_train_samples = len(generator_top.filenames)  
num_classes = len(generator_top.class_indices)  


train_data = np.load('../data/output_convnet/inception_bnfeatures_train.npy')

# get the class lebels for the training data, in the original order  
train_labels = generator_top.classes  

# convert the training labels to categorical vectors  
train_labels = to_categorical(train_labels, num_classes=num_classes)



generator_top = datagen_top.flow_from_directory(  
    validation_data_dir,  
    target_size=(img_width, img_height),  
    batch_size=batch_size,  
    class_mode=None,  
    shuffle=False,
    interpolation = 'lanczos')  

nb_validation_samples = len(generator_top.filenames)  

validation_data = np.load('../data/output_convnet/inception_bnfeatures_val.npy')  

validation_labels = generator_top.classes  
validation_labels = to_categorical(validation_labels, num_classes=num_classes)

# top model
model = Sequential()
# model.add(Flatten(input_shape=train_data.shape[1:]))
model.add(GlobalAveragePooling2D(input_shape=train_data.shape[1:]))
model.add(Dense(1024, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))  

model.compile(optimizer=SGD(lr=0.001),
              loss='categorical_crossentropy', metrics=['accuracy']) 

history = model.fit(train_data, train_labels,
                    epochs=epochs,
                    batch_size=batch_size,
                    validation_data=(validation_data, validation_labels))  

model.save_weights('../data/output_convnet/bn_inception_model.h5')  

(eval_loss, eval_accuracy) = model.evaluate(
    validation_data, validation_labels, batch_size=batch_size, verbose=1)

print()
print()
print("acc: {:.2f}%".format(eval_accuracy * 100))  
print("loss: {}".format(eval_loss))

plt.figure(1)  
   
# summarize history for accuracy  

plt.subplot(211)  
plt.plot(history.history['acc'])  
plt.plot(history.history['val_acc'])  
plt.title('model accuracy')  
plt.ylabel('accuracy')  
plt.xlabel('epoch')  
plt.legend(['train', 'test'], loc='upper left')  

# summarize history for loss  

plt.subplot(212)  
plt.plot(history.history['loss'])  
plt.plot(history.history['val_loss'])  
plt.title('model loss')  
plt.ylabel('loss')  
plt.xlabel('epoch')  
plt.legend(['train', 'test'], loc='upper left')

PATH_TO_OUTPUT = "../data/output_convnet"
plt.savefig(os.path.join(PATH_TO_OUTPUT, "bn_inception.png"), bbox_inches='tight') # png 70kb vs jpg 135 kb

plt.show()

tf_bn_train = time.time()    
tt_bn_train = tf_bn_train - ti_bn_train
print(time.strftime("%H:%M:%S", time.gmtime(tt_bn_train)))
# Out:
# Found 3000 images belonging to 8 classes.
# Found 1000 images belonging to 8 classes.
# Train on 3000 samples, validate on 1000 samples
# Epoch 1
# Epoch 42/50
# 3000/3000 [==============================] - 1s 350us/step - loss: 0.2552 - acc: 0.9413 - val_loss: 0.4795 - val_acc: 0.8510
# Epoch 43/50
# 3000/3000 [==============================] - 1s 336us/step - loss: 0.2507 - acc: 0.9443 - val_loss: 0.4839 - val_acc: 0.8500
# Epoch 44/50
# 3000/3000 [==============================] - 1s 333us/step - loss: 0.2468 - acc: 0.9450 - val_loss: 0.4827 - val_acc: 0.8480
# Epoch 45/50
# 3000/3000 [==============================] - 1s 355us/step - loss: 0.2433 - acc: 0.9443 - val_loss: 0.4752 - val_acc: 0.8480
# Epoch 46/50
# 3000/3000 [==============================] - 1s 367us/step - loss: 0.2394 - acc: 0.9487 - val_loss: 0.4771 - val_acc: 0.8510
# Epoch 47/50
# 3000/3000 [==============================] - 1s 391us/step - loss: 0.2356 - acc: 0.9487 - val_loss: 0.4733 - val_acc: 0.8510
# Epoch 48/50
# 3000/3000 [==============================] - 1s 321us/step - loss: 0.2320 - acc: 0.9497 - val_loss: 0.4778 - val_acc: 0.8480
# Epoch 49/50
# 3000/3000 [==============================] - 1s 332us/step - loss: 0.2289 - acc: 0.9500 - val_loss: 0.4717 - val_acc: 0.8540
# Epoch 50/50
# 3000/3000 [==============================] - 1s 336us/step - loss: 0.2254 - acc: 0.9493 - val_loss: 0.4732 - val_acc: 0.8560
# 1000/1000 [==============================] - 0s 120us/step
#
#
# acc: 85.60%
# loss: 0.4731604319810867
# 00:00:52

# %%
import h5py
hdf5_file = h5py.File('../data/output_convnet/bn_inception_model.h5', mode='r')
print(list(hdf5_file))
# Out:
# ['dense_1', 'dense_2', 'global_average_pooling2d_1']

# %%
top_model_weights_path = '../data/output_convnet/bn_inception_model.h5'

batch_size = 5 # con 5 funciona con 16 es imposible probar con 10

# %%
from keras import applications
from keras.preprocessing.image import ImageDataGenerator
# from keras import optimizers
from keras.optimizers import SGD
from keras.models import Sequential
from keras.layers import Dropout, Flatten, Dense

from keras import applications
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers
from keras.models import Sequential, Model
from keras.layers import Dropout, Flatten, Dense, Input

# %%
input_tensor = Input(shape=(img_width,img_height,3))
base_model = InceptionV3(weights='imagenet', include_top=False, input_tensor=input_tensor)
print("model loaded")
# Out:
# model loaded

# %%
base_model.output_shape[1:]
# Out:
# (3, 3, 2048)

# %%
# build a classifier model to put on top of the convolutional model
top_model = Sequential()
# model.add(Flatten(input_shape=train_data.shape[1:]))
top_model.add(GlobalAveragePooling2D(input_shape=train_data.shape[1:]))
top_model.add(Dense(1024, activation='relu'))
top_model.add(Dense(num_classes, activation='softmax'))

# %%
# for i, layer in enumerate(base_model.layers):
#     print (i, layer.name, layer.output_shape)

# %%
for i, layer in enumerate(top_model.layers):
    print (i, layer.name, layer.output_shape)
# Out:
# 0 global_average_pooling2d_2 (None, 2048)
# 1 dense_3 (None, 1024)
# 2 dense_4 (None, 8)

# %%
top_model.load_weights("../data/output_convnet/bn_inception_model.h5")

# %%
model_total = Model(input= base_model.input, output= top_model(base_model.output))
# Out:
# /home/jon/anaconda3/envs/test/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("se...)`
#   """Entry point for launching an IPython kernel.

# %%
for layer in model_total.layers[:280]:
    layer.trainable = False
for layer in model_total.layers[280:]:
    layer.trainable = True

# %%
# for i, layer in enumerate(model_total.layers):
#     if layer.trainable:
#         print("layer {0:d}, {1:s} is trainable".format(i, layer.name))
#     else:
#         print("layer {0:d}, {1:s} is freezed".format(i, layer.name))

# %%
model_total.compile(optimizer=SGD(lr=0.0001, momentum=0.9),
              loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# prepare data augmentation configuration
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1. / 255)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical')
# Out:
# Found 3000 images belonging to 8 classes.
# Found 1000 images belonging to 8 classes.

# %%
import time
# fine-tune the model

# añadir medidas de acc loss como el bottleneck

ti_ftuning = time.time()


historical_data = model_total.fit_generator(
    train_generator,
    samples_per_epoch=nb_train_samples,
    epochs=epochs,
    verbose = 1,
    validation_data=validation_generator,
    validation_steps=nb_validation_samples)

tf_ftuning = time.time()
tt_ftuning = tf_ftuning - ti_ftuning
print(time.strftime("%H:%M:%S", time.gmtime(tt_ftuning)))
# Out:
# /home/jon/anaconda3/envs/test/lib/python3.6/site-packages/ipykernel_launcher.py:15: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras.pre..., epochs=50, verbose=1, validation_data=<keras.pre..., validation_steps=1000, steps_per_epoch=600)`
#   from ipykernel import kernelapp as app
# Epoch 1/50
# 600/600 [==============================] - 72s 120ms/step - loss: 1.2374 - acc: 0.5577 - val_loss: 1.8793 - val_acc: 0.6200
# Epoch 2/50
# 600/600 [==============================] - 66s 110ms/step - loss: 1.0006 - acc: 0.6583 - val_loss: 1.8279 - val_acc: 0.6570
# Epoch 3/50
# 600/600 [==============================] - 66s 110ms/step - loss: 0.9070 - acc: 0.6907 - val_loss: 2.2644 - val_acc: 0.6550
# Epoch 4/50
# 600/600 [==============================] - 66s 111ms/step - loss: 0.8731 - acc: 0.6983 - val_loss: 2.5414 - val_acc: 0.6500
# Epoch 5/50
# 600/600 [==============================] - 66s 110ms/step - loss: 0.8080 - acc: 0.7183 - val_loss: 2.5194 - val_acc: 0.6490
# Epoch 6/50
# 600/600 [==============================] - 66s 111ms/step - loss: 0.7978 - acc: 0.7220 - val_loss: 2.5602 - val_acc: 0.6630
# Epoch 7/50
# 600/600 [==============================] - 66s 111ms/step - loss: 0.7673 - acc: 0.7283 - val_loss: 2.5645 - val_acc: 0.6750
# Epoch 8/50
# 600/600 [==============================] - 66s 111ms/step - loss: 0.7479 - acc: 0.7343 - val_loss: 2.8602 - val_acc: 0.6520
# Epoch 9/50
# 600/600 [==============================] - 66s 111ms/step - loss: 0.7265 - acc: 0.7473 - val_loss: 2.5049 - val_acc: 0.6880
# Epoch 10/50
# 600/600 [==============================] - 67s 111ms/step - loss: 0.7145 - acc: 0.7593 - val_loss: 2.7384 - val_acc: 0.6770
# Epoch 11/50
# 600/600 [==============================] - 66s 110ms/step - loss: 0.7146 - acc: 0.7470 - val_loss: 2.6556 - val_acc: 0.6620
# Epoch 12/50
# 600/600 [==============================] - 66s 111ms/step - loss: 0.6921 - acc: 0.7567 - val_loss: 2.6827 - val_acc: 0.6780
# Epoch 13/50
# 600/600 [==============================] - 66s 110ms/step - loss: 0.7196 - acc: 0.7437 - val_loss: 2.6619 - val_acc: 0.6740
# Epoch 14/50
# 600/600 [==============================] - 66s 110ms/step - loss: 0.6416 - acc: 0.7680 - val_loss: 2.6244 - val_acc: 0.6750
# Epoch 15/50
# 600/600 [==============================] - 67s 111ms/step - loss: 0.6875 - acc: 0.7633 - val_loss: 2.5407 - val_acc: 0.6800
# Epoch 16/50
# 600/600 [==============================] - 66s 110ms/step - loss: 0.6863 - acc: 0.7547 - val_loss: 2.7176 - val_acc: 0.6770
# Epoch 17/50
# 600/600 [==============================] - 66s 110ms/step - loss: 0.6734 - acc: 0.7690 - val_loss: 2.6343 - val_acc: 0.6860
# Epoch 18/50
# 600/600 [==============================] - 66s 111ms/step - loss: 0.6232 - acc: 0.7740 - val_loss: 2.6295 - val_acc: 0.6900
# Epoch 19/50
# 600/600 [==============================] - 66s 111ms/step - loss: 0.6408 - acc: 0.7817 - val_loss: 2.6465 - val_acc: 0.6810
# Epoch 20/50
# 600/600 [==============================] - 66s 111ms/step - loss: 0.6625 - acc: 0.7667 - val_loss: 2.6072 - val_acc: 0.6890
# Epoch 21/50
# 600/600 [==============================] - 66s 110ms/step - loss: 0.
# 600/600 [==============================] - 66s 110ms/step - loss: 0.5536 - acc: 0.8143 - val_loss: 2.7839 - val_acc: 0.6750
# Epoch 50/50
# 600/600 [==============================] - 66s 109ms/step - loss: 0.5386 - acc: 0.8100 - val_loss: 2.6585 - val_acc: 0.6850
# 00:55:08

# %%
import matplotlib.pyplot as plt
PATH_TO_DF = "../data/output_convnet"

acc = historical_data.history['acc']
val_acc = historical_data.history['val_acc']
loss = historical_data.history['loss']
val_loss = historical_data.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
model_total.save_weights('../data/output_convnet/ft_inception_model.h5')

# %%
import h5py
hdf5_file = h5py.File('../data/output_convnet/ft_inception_model.h5', mode='r')
print(list(hdf5_file))
# Out:
# ['activation_100', 'activation_101', 'activation_102', 'activation_103', 'activation_104', 'activation_105', 'activation_106', 'activation_107', 'activation_108', 'activation_109', 'activation_110', 'activation_111', 'activation_112', 'activation_113', 'activation_114', 'activation_115', 'activation_116', 'activation_117', 'activation_118', 'activation_119', 'activation_120', 'activation_121', 'activation_122', 'activation_123', 'activation_124', 'activation_125', 'activation_126', 'activation_127', 'activation_128', 'activation_129', 'activation_130', 'activation_131', 'activation_132', 'activation_133', 'activation_134', 'activation_135', 'activation_136', 'activation_137', 'activation_138', 'activation_139', 'activation_140', 'activation_141', 'activation_142', 'activation_143', 'activation_144', 'activation_145', 'activation_146', 'activation_147', 'activation_148', 'activation_149', 'activation_150', 'activation_151', 'activation_152', 'activation_153', 'activation_154', 'activation_155', 'activation_156', 'activation_157', 'activation_158', 'activation_159', 'activation_160', 'activation_161', 'activation_162', 'activation_163', 'activation_164', 'activation_165', 'activation_166', 'activation_167', 'activation_168', 'activation_169', 'activation_170', 'activation_171', 'activation_172', 'activation_173', 'activation_174', 'activation_175', 'activation_176', 'activation_177', 'activation_178', 'activation_179', 'activation_180', 'activation_181', 'activation_182', 'activation_183', 'activation_184', 'activation_185', 'activation_186', 'activation_187', 'activation_188', 'activation_95', 'activation_96', 'activation_97', 'activation_98', 'activation_99', 'average_pooling2d_10', 'average_pooling2d_11', 'average_pooling2d_12', 'average_pooling2d_13', 'average_pooling2d_14', 'average_pooling2d_15', 'average_pooling2d_16', 'average_pooling2d_17', 'average_pooling2d_18', 'batch_normalization_100', 'batch_normalization_101', 'batch_normalization_102', 'batch_normalization_103', 'batch_normalization_104', 'batch_normalization_105', 'batch_normalization_106', 'batch_normalization_107', 'batch_normalization_108', 'batch_normalization_109', 'batch_normalization_110', 'batch_normalization_111', 'batch_normalization_112', 'batch_normalization_113', 'batch_normalization_114', 'batch_normalization_115', 'batch_normalization_116', 'batch_normalization_117', 'batch_normalization_118', 'batch_normalization_119', 'batch_normalization_120', 'batch_normalization_121', 'batch_normalization_122', 'batch_normalization_123', 'batch_normalization_124', 'batch_normalization_125', 'batch_normalization_126', 'batch_normalization_127', 'batch_normalization_128', 'batch_normalization_129', 'batch_normalization_130', 'batch_normalization_131', 'batch_normalization_132', 'batch_normalization_133', 'batch_normalization_134', 'batch_normalization_135', 'batch_normalization_136', 'batch_normalization_137', 'batch_normalization_138', 'batch_normalization_139', 'batch_normalization_140', 'batch_normalization_141', 'batch_normalization_142', 'batch_normalization_143', 'batch_normalization_144', 'batch_normalization_145', 'batch_normalization_146', 'batch_normalization_147', 'batch_normalization_148', 'batch_normalization_149', 'batch_normalization_150', 'batch_normalization_151', 'batch_normalization_152', 'batch_normalization_153', 'batch_normalization_154', 'batch_normalization_155', 'batch_normalization_156', 'batch_normalization_157', 'batch_normalization_158', 'batch_normalization_159', 'batch_normalization_160', 'batch_normalization_161', 'batch_normalization_162', 'batch_normalization_163', 'batch_normalization_164', 'batch_normalization_165', 'batch_normalization_166', 'batch_normalization_167', 'batch_normalization_168', 'batch_normalization_169', 'batch_normalization_170', 'batch_normalization_171', 'batch_normalization_172', 'batch_normalization_173', 'batch_normalization_174', 'batch_normalization_175', 'batch_normalization_176', 'batch_normalizat ...

# %%
# build the VGG16 network
# input_tensor = Input(shape=(img_width,img_height,3))
model_base_pred = InceptionV3(weights='imagenet', include_top=False, input_tensor=input_tensor)  
print("model base for predition loaded")

# build top model  
top_model = Sequential()
# model.add(Flatten(input_shape=train_data.shape[1:]))
top_model.add(GlobalAveragePooling2D(input_shape=train_data.shape[1:]))
top_model.add(Dense(1024, activation='relu'))
top_model.add(Dense(num_classes, activation='softmax'))
print()
print("model top for predition loaded")
# Out:
# model base for predition loaded
#
# model top for predition loaded

# %%
model_total_pred = Model(input= model_base_pred.input, output= top_model(model_base_pred.output))
# Out:
# /home/jon/anaconda3/envs/test/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("se...)`
#   """Entry point for launching an IPython kernel.

# %%
# for i, layer in enumerate(model_total_pred.layers):
#     print (i, layer.name, layer.output_shape)

# %%
# cargamos los pesos anteriormente obtenidos en el entrenamiento
model_total_pred.load_weights("../data/output_convnet/ft_inception_model.h5")

# %%
test_data_dir = 'test/'
batch_size_test = 5 # probamos con esto

test_convnet = ImageDataGenerator(rescale=1. / 255)

test_generator = test_convnet.flow_from_directory(
    test_data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    shuffle =False,
    class_mode='categorical')

cat_dict = test_generator.class_indices

inverse_coding = {v: k for k, v in cat_dict.items()}
# Out:
# Found 1000 images belonging to 8 classes.

# %%
import os

test_data_dir = "test/"

# listado del train
img_test_real = [] # listado de las imagenes pareado con img_cat_real
img_cat_real = [] # categorias de las imagenes


img_cat_pred = [] # elementos predichos por la convnet

img_folder = sorted([folder for folder in os.listdir(test_data_dir)
                  if os.path.isdir(os.path.join(test_data_dir, folder))])

for index_folder, category in enumerate(img_folder):
    
    folder = os.path.join(test_data_dir, category)

    for index_img, img in enumerate(os.listdir(folder)):
        
        if img.endswith(".tif"): # just in case there are other kind of files like .db
            img_test_real.append(os.path.join(folder, img))
            img_cat_real.append(img_folder[index_folder])

    print("Category {0:s} has {1:d} images.".format(category, index_img+1))
# Out:
# Category 01_TUMOR has 130 images.
# Category 02_STROMA has 124 images.
# Category 03_COMPLEX has 132 images.
# Category 04_LYMPHO has 112 images.
# Category 05_DEBRIS has 117 images.
# Category 06_MUCOSA has 127 images.
# Category 07_ADIPOSE has 131 images.
# Category 08_EMPTY has 127 images.

# %%
from keras.preprocessing import image
import numpy as np
from keras.applications.vgg16 import preprocess_input

# %%
print(len(img_cat_pred))
print(len(img_test_real))
# Out:
# 0
# 1000

# %%
for index, img_path in enumerate(img_test_real):
    
    
    if not index % 100:
        print("image {0:d} processed".format(index))
        
    # pre process
    img = image.load_img(img_path, target_size=(150, 150))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    
    x = x / 255
    
    # prediction
    x = model_total_pred.predict(x)
    
    # label
    label = inverse_coding[np.argmax(x)]
    
#     print(label)
    
    # store the label
    img_cat_pred.append(label)
# Out:
# image 0 processed
# 06_MUCOSA
# 01_TUMOR
# 02_STROMA
# 04_LYMPHO
# 04_LYMPHO
# 04_LYMPHO
# 04_LYMPHO
# 04_LYMPHO
# 04_LYMPHO
# 08_EMPTY
# 05_DEBRIS
# 04_LYMPHO
# 01_TUMOR
# 04_LYMPHO
# 06_MUCOSA
# 08_EMPTY
# 01_TUMOR
# 01_TUMOR
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 08_EMPTY
# 01_TUMOR
# 05_DEBRIS
# 04_LYMPHO
# 08_EMPTY
# 08_EMPTY
# 05_DEBRIS
# 08_EMPTY
# 07_ADIPOSE
# 08_EMPTY
# 01_TUMOR
# 05_DEBRIS
# 04_LYMPHO
# 08_EMPTY
# 01_TUMOR
# 08_EMPTY
# 01_TUMOR
# 08_EMPTY
# 01_TUMOR
# 01_TUMOR
# 04_LYMPHO
# 07_ADIPOSE
# 05_DEBRIS
# 04_LYMPHO
# 01_TUMOR
# 08_EMPTY
# 04_LYMPHO
# 08_EMPTY
# 04_LYMPHO
# 01_TUMOR
# 08_EMPTY
# 04_LYMPHO
# 03_COMPLEX
# 08_EMPTY
# 04_LYMPHO
# 01_TUMOR
# 04_LYMPHO
# 04_LYMPHO
# 01_TUMOR
# 01_TUMOR
# 04_LYMPHO
# 07_ADIPOSE
# 06_MUCOSA
# 06_MUCOSA
# 07_ADIPOSE
# 08_EMPTY
# 01_TUMOR
# 03_COMPLEX
# 04_LYMPHO
# 06_MUCOSA
# 08_EMPTY
# 08_EMPTY
# 07_ADIPOSE
# 04_LYMPHO
# 04_LYMPHO
# 04_LYMPHO
# 01_TUMOR
# 01_TUMOR
# 05_DEBRIS
# 08_EMPTY
# 04_LYMPHO
# 01_TUMOR
# 04_LYMPHO
# 04_LYMPHO
# 08_EMPTY
# 05_DEBRIS
# 04_LYMPHO
# 04_LYMPHO
# 04_LYMPHO
# 04_LYMPHO
# 08_EMPTY
# 01_TUMOR
# 08_EMPTY
# 08_EMPTY
# 08_EMPTY
# 01_TUMOR
# 01_TUMOR
# 08_EMPTY
# 04_LYMPHO
# image 100 processed
# 01_TUMOR
# 04_LYMPHO
# 08_EMPTY
# 06_MUCOSA
# 04_LYMPHO
# 01_TUMOR
# 08_EMPTY
# 04_LYMPHO
# 06_MUCOSA
# 03_COMPLEX
# 01_TUMOR
# 08_EMPTY
# 04_LYMPHO
# 04_LYMPHO
# 07_ADIPOSE
# 04_LYMPHO
# 04_LYMPHO
# 01_TUMOR
# 07_ADIPOSE
# 07_ADIPOSE
# 01_TUMOR
# 07_ADIPOSE
# 01_TUMOR
# 04_LYMPHO
# 08_EMPTY
# 01_TUMOR
# 08_EMPTY
# 08_EMPTY
# 02_STROMA
# 08_EMPTY
# 01_TUMOR
# 02_STROMA
# 05_DEBRIS
# 07_ADIPOSE
# 03_COMPLEX
# 05_DEBRIS
# 02_STROMA
# 02_STROMA
# 05_DEBRIS
# 02_STROMA
# 07_ADIPOSE
# 05_DEBRIS
# 05_DEBRIS
# 02_STROMA
# 05_DEBRIS
# 08_EMPTY
# 08_EMPTY
# 04_LYMPHO
# 05_DEBRIS
# 05_DEBRIS
# 06_MUCOSA
# 02_STROMA
# 07_ADIPOSE
# 08_EMPTY
# 07_ADIPOSE
# 05_DEBRIS
# 08_EMPTY
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 02_STROMA
# 05_DEBRIS
# 02_STROMA
# 07_ADIPOSE
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 02_STROMA
# 05_DEBRIS
# 05_DEBRIS
# 02_STROMA
# 04_LYMPHO
# 04_LYMPHO
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 01_TUMOR
# 04_LYMPHO
# 05_DEBRIS
# 08_EMPTY
# 06_MUCOSA
# 07_ADIPOSE
# 02_STROMA
# 08_EMPTY
# 05_DEBRIS
# 05_DEBRIS
# 04_LYMPHO
# 08_EMPTY
# 05_DEBRIS
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 05_DEBRIS
# 01_TUMOR
# 07_ADIPOSE
# 08_EMPTY
# 08_EMPTY
# 02_STROMA
# image 200 processed
# 05_DEBRIS
# 05_DEBRIS
# 04_LYMPHO
# 02_STROMA
# 04_LYMPHO
# 02_STROMA
# 07_ADIPOSE
# 07_ADIPOSE
# 05_DEBRIS
# 02_STROMA
# 05_DEBRIS
# 02_STROMA
# 04_LYMPHO
# 05_DEBRIS
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 05_DEBRIS
# 07_ADIPOSE
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 08_EMPTY
# 04_LYMPHO
# 07_ADIPOSE
# 05_DEBRIS
# 05_DEBRIS
# 08_EMPTY
# 05_DEBRIS
# 02_STROMA
# 08_EMPTY
# 08_EMPTY
# 05_DEBRIS
# 08_EMPTY
# 07_ADIPOSE
# 07_ADIPOSE
# 05_DEBRIS
# 08_EMPTY
# 07_ADIPOSE
# 08_EMPTY
# 02_STROMA
# 05_DEBRIS
# 02_STROMA
# 07_ADIPOSE
# 01_TUMOR
# 02_STROMA
# 05_DEBRIS
# 05_DEBRIS
# 07_ADIPOSE
# 05_DEBRIS
# 02_STROMA
# 05_DEBRIS
# 05_DEBRIS
# 04_LYMPHO
# 08_EMPTY
# 08_EMPTY
# 06_MUCOSA
# 08_EMPTY
# 08_EMPTY
# 08_EMPTY
# 08_EMPTY
# 05_DEBRIS
# 08_EMPTY
# 05_DEBRIS
# 03_COMPLEX
# 05_DEBRIS
# 05_DEBRIS
# 02_STROMA
# 05_DEBRIS
# 08_EMPTY
# 08_EMPTY
# 04_LYMPHO
# 08_EMPTY
# 08_EMPTY
# 03_COMPLEX
# 08_EMPTY
# 08_EMPTY
# 08_EMPTY
# 05_DEBRIS
# 08_EMPTY
# 08_EMPTY
# 08_EMPTY
# 08_EMPTY
# 08_EMPTY
# 05_DEBRIS
# 08_EMPTY
# 05_DEBRIS
# 08_EMPTY
# 05_DEBRIS
# 08_EMPTY
# 05_DEBRIS
# 08_EMPTY
# 08_EMPTY
# 08_EMPTY
# 08_EMPTY
# 08_EMPTY
# 08_EMPTY
# 08_EMPTY
# 08_EMPTY
# 08_EMPTY
# image 300 processed
# 08_EMPTY
# 01_TUMOR
# 02_STROMA
# 08_EMPTY
# 08_EMPTY
# 01_TUMOR
# 08_EMPTY
# 03_COMPLEX
# 05_DEBRIS
# 08_EMPTY
# 08_EMPTY
# 05_DEBRIS
# 08_EMPTY
# 02_STROMA
# 05_DEBRIS
# 05_DEBRIS
# 08_EMPTY
# 04_LYMPHO
# 05_DEBRIS
# 05_DEBRIS
# 08_EMPTY
# 08_EMPTY
# 05_DEBRIS
# 08_EMPTY
# 08_EMPTY
# 08_EMPTY
# 05_DEBRIS
# 05_DEBRIS
# 03_COMPLEX
# 08_EMPTY
# 08_EMPTY
# 04_LYMPHO
# 05_DEBRIS
# 08_EMPTY
# 06_MUCOSA
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 03_COMPLEX
# 07_ADIPOSE
# 03_COMPLEX
# 05_DEBRIS
# 05_DEBRIS
# 08_EMPTY
# 04_LYMPHO
# 05_DEBRIS
# 05_DEBRIS
# 04_LYMPHO
# 04_LYMPHO
# 07_ADIPOSE
# 05_DEBRIS
# 02_STROMA
# 04_LYMPHO
# 01_TUMOR
# 05_DEBRIS
# 08_EMPTY
# 08_EMPTY
# 05_DEBRIS
# 08_EMPTY
# 08_EMPTY
# 05_DEBRIS
# 08_EMPTY
# 04_LYMPHO
# 07_ADIPOSE
# 05_DEBRIS
# 01_TUMOR
# 08_EMPTY
# 04_LYMPHO
# 08_EMPTY
# 05_DEBRIS
# 08_EMPTY
# 05_DEBRIS
# 05_DEBRIS
# 04_LYMPHO
# 05_DEBRIS
# 08_EMPTY
# 08_EMPTY
# 05_DEBRIS
# 08_EMPTY
# 08_EMPTY
# 08_EMPTY
# 08_EMPTY
# 05_DEBRIS
# 03_COMPLEX
# 08_EMPTY
# 05_DEBRIS
# 08_EMPTY
# 03_COMPLEX
# 07_ADIPOSE
# 06_MUCOSA
# 04_LYMPHO
# 07_ADIPOSE
# 04_LYMPHO
# 01_TUMOR
# 07_ADIPOSE
# 06_MUCOSA
# 03_COMPLEX
# 01_TUMOR
# 08_EMPTY
# 06_MUCOSA
# image 400 processed
# 07_ADIPOSE
# 08_EMPTY
# 01_TUMOR
# 06_MUCOSA
# 06_MUCOSA
# 08_EMPTY
# 08_EMPTY
# 08_EMPTY
# 06_MUCOSA
# 07_ADIPOSE
# 08_EMPTY
# 06_MUCOSA
# 05_DEBRIS
# 07_ADIPOSE
# 08_EMPTY
# 06_MUCOSA
# 04_LYMPHO
# 08_EMPTY
# 06_MUCOSA
# 08_EMPTY
# 06_MUCOSA
# 01_TUMOR
# 08_EMPTY
# 04_LYMPHO
# 06_MUCOSA
# 08_EMPTY
# 07_ADIPOSE
# 01_TUMOR
# 04_LYMPHO
# 06_MUCOSA
# 01_TUMOR
# 03_COMPLEX
# 04_LYMPHO
# 06_MUCOSA
# 08_EMPTY
# 01_TUMOR
# 06_MUCOSA
# 01_TUMOR
# 01_TUMOR
# 01_TUMOR
# 08_EMPTY
# 06_MUCOSA
# 01_TUMOR
# 06_MUCOSA
# 08_EMPTY
# 06_MUCOSA
# 08_EMPTY
# 04_LYMPHO
# 07_ADIPOSE
# 01_TUMOR
# 01_TUMOR
# 01_TUMOR
# 06_MUCOSA
# 07_ADIPOSE
# 08_EMPTY
# 07_ADIPOSE
# 01_TUMOR
# 06_MUCOSA
# 08_EMPTY
# 06_MUCOSA
# 08_EMPTY
# 08_EMPTY
# 06_MUCOSA
# 08_EMPTY
# 06_MUCOSA
# 07_ADIPOSE
# 06_MUCOSA
# 07_ADIPOSE
# 07_ADIPOSE
# 01_TUMOR
# 06_MUCOSA
# 01_TUMOR
# 06_MUCOSA
# 01_TUMOR
# 01_TUMOR
# 08_EMPTY
# 06_MUCOSA
# 05_DEBRIS
# 06_MUCOSA
# 08_EMPTY
# 01_TUMOR
# 01_TUMOR
# 08_EMPTY
# 06_MUCOSA
# 06_MUCOSA
# 06_MUCOSA
# 01_TUMOR
# 04_LYMPHO
# 03_COMPLEX
# 01_TUMOR
# 01_TUMOR
# 06_MUCOSA
# 06_MUCOSA
# 03_COMPLEX
# 07_ADIPOSE
# 01_TUMOR
# 08_EMPTY
# 05_DEBRIS
# 05_DEBRIS
# 04_LYMPHO
# image 500 processed
# 05_DEBRIS
# 04_LYMPHO
# 05_DEBRIS
# 05_DEBRIS
# 04_LYMPHO
# 04_LYMPHO
# 04_LYMPHO
# 03_COMPLEX
# 05_DEBRIS
# 07_ADIPOSE
# 04_LYMPHO
# 04_LYMPHO
# 05_DEBRIS
# 04_LYMPHO
# 05_DEBRIS
# 05_DEBRIS
# 08_EMPTY
# 05_DEBRIS
# 05_DEBRIS
# 04_LYMPHO
# 05_DEBRIS
# 04_LYMPHO
# 01_TUMOR
# 08_EMPTY
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 08_EMPTY
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 07_ADIPOSE
# 08_EMPTY
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 02_STROMA
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 01_TUMOR
# 05_DEBRIS
# 05_DEBRIS
# 04_LYMPHO
# 08_EMPTY
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 07_ADIPOSE
# 02_STROMA
# 08_EMPTY
# 02_STROMA
# 04_LYMPHO
# 07_ADIPOSE
# 07_ADIPOSE
# 05_DEBRIS
# 04_LYMPHO
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 04_LYMPHO
# 04_LYMPHO
# 05_DEBRIS
# 05_DEBRIS
# 04_LYMPHO
# 05_DEBRIS
# 05_DEBRIS
# 07_ADIPOSE
# 01_TUMOR
# 04_LYMPHO
# 05_DEBRIS
# 04_LYMPHO
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 04_LYMPHO
# 05_DEBRIS
# 01_TUMOR
# 05_DEBRIS
# 07_ADIPOSE
# 02_STROMA
# 05_DEBRIS
# 04_LYMPHO
# 07_ADIPOSE
# 07_ADIPOSE
# 02_STROMA
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 04_LYMPHO
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 08_EMPTY
# 04_LYMPHO
# image 600 processed
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 04_LYMPHO
# 01_TUMOR
# 05_DEBRIS
# 07_ADIPOSE
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 07_ADIPOSE
# 06_MUCOSA
# 05_DEBRIS
# 01_TUMOR
# 06_MUCOSA
# 06_MUCOSA
# 05_DEBRIS
# 07_ADIPOSE
# 01_TUMOR
# 07_ADIPOSE
# 01_TUMOR
# 07_ADIPOSE
# 06_MUCOSA
# 01_TUMOR
# 07_ADIPOSE
# 06_MUCOSA
# 07_ADIPOSE
# 06_MUCOSA
# 07_ADIPOSE
# 08_EMPTY
# 06_MUCOSA
# 01_TUMOR
# 01_TUMOR
# 06_MUCOSA
# 08_EMPTY
# 07_ADIPOSE
# 07_ADIPOSE
# 06_MUCOSA
# 05_DEBRIS
# 06_MUCOSA
# 05_DEBRIS
# 06_MUCOSA
# 06_MUCOSA
# 08_EMPTY
# 08_EMPTY
# 04_LYMPHO
# 08_EMPTY
# 06_MUCOSA
# 07_ADIPOSE
# 05_DEBRIS
# 06_MUCOSA
# 08_EMPTY
# 06_MUCOSA
# 07_ADIPOSE
# 04_LYMPHO
# 05_DEBRIS
# 01_TUMOR
# 06_MUCOSA
# 05_DEBRIS
# 05_DEBRIS
# 06_MUCOSA
# 01_TUMOR
# 08_EMPTY
# 06_MUCOSA
# 05_DEBRIS
# 07_ADIPOSE
# 06_MUCOSA
# 06_MUCOSA
# 05_DEBRIS
# 04_LYMPHO
# 05_DEBRIS
# 08_EMPTY
# 06_MUCOSA
# 04_LYMPHO
# 05_DEBRIS
# 07_ADIPOSE
# 05_DEBRIS
# 06_MUCOSA
# 06_MUCOSA
# 06_MUCOSA
# 05_DEBRIS
# 04_LYMPHO
# 01_TUMOR
# 06_MUCOSA
# 05_DEBRIS
# 04_LYMPHO
# 06_MUCOSA
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 06_MUCOSA
# 06_MUCOSA
# 04_LYMPHO
# 06_MUCOSA
# 07_ADIPOSE
# 06_MUCOSA
# image 700 processed
# 07_ADIPOSE
# 06_MUCOSA
# 06_MUCOSA
# 06_MUCOSA
# 05_DEBRIS
# 08_EMPTY
# 05_DEBRIS
# 08_EMPTY
# 06_MUCOSA
# 05_DEBRIS
# 05_DEBRIS
# 06_MUCOSA
# 06_MUCOSA
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 08_EMPTY
# 06_MUCOSA
# 05_DEBRIS
# 06_MUCOSA
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 08_EMPTY
# 05_DEBRIS
# 05_DEBRIS
# 07_ADIPOSE
# 05_DEBRIS
# 07_ADIPOSE
# 06_MUCOSA
# 07_ADIPOSE
# 05_DEBRIS
# 06_MUCOSA
# 05_DEBRIS
# 05_DEBRIS
# 06_MUCOSA
# 06_MUCOSA
# 05_DEBRIS
# 03_COMPLEX
# 06_MUCOSA
# 05_DEBRIS
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 03_COMPLEX
# 07_ADIPOSE
# 05_DEBRIS
# 05_DEBRIS
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 05_DEBRIS
# 07_ADIPOSE
# 05_DEBRIS
# 05_DEBRIS
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 05_DEBRIS
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 05_DEBRIS
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# image 800 processed
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 05_DEBRIS
# 01_TUMOR
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 05_DEBRIS
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 05_DEBRIS
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 05_DEBRIS
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 05_DEBRIS
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 05_DEBRIS
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 05_DEBRIS
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 05_DEBRIS
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 05_DEBRIS
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 07_ADIPOSE
# 05_DEBRIS
# 01_TUMOR
# 05_DEBRIS
# 07_ADIPOSE
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 07_ADIPOSE
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 07_ADIPOSE
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 01_TUMOR
# image 900 processed
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 01_TUMOR
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 07_ADIPOSE
# 05_DEBRIS
# 01_TUMOR
# 05_DEBRIS
# 01_TUMOR
# 07_ADIPOSE
# 05_DEBRIS
# 07_ADIPOSE
# 08_EMPTY
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 07_ADIPOSE
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 08_EMPTY
# 07_ADIPOSE
# 07_ADIPOSE
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 01_TUMOR
# 01_TUMOR
# 05_DEBRIS
# 05_DEBRIS
# 07_ADIPOSE
# 01_TUMOR
# 05_DEBRIS
# 01_TUMOR
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 01_TUMOR
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 07_ADIPOSE
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 07_ADIPOSE
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 07_ADIPOSE
# 01_TUMOR
# 05_DEBRIS
# 01_TUMOR
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 05_DEBRIS
# 07_ADIPOSE
# 01_TUMOR

# %%
print(len(img_cat_pred))
print(len(img_test_real))
# Out:
# 1000
# 1000

# %%
img_cat_pred_arr = np.array(img_cat_pred)
img_cat_real_arr = np.array(img_cat_real)

# %%
print(len(img_cat_pred_arr))
print(len(img_cat_real_arr))
# Out:
# 1000
# 1000

# %%
from sklearn.metrics import confusion_matrix
ft_conf_mat = confusion_matrix(img_cat_real_arr,img_cat_pred_arr)

# %%
ft_conf_mat
# Out:
# array([[ 29,   2,   3,  39,   7,   7,  12,  31],
#        [  4,  21,   1,  10,  48,   2,  22,  16],
#        [  4,   4,   7,  10,  39,   2,   3,  63],
#        [ 25,   0,   5,   8,   3,  32,  14,  25],
#        [  5,   5,   1,  23,  65,   0,  11,   7],
#        [  9,   0,   1,   7,  38,  43,  17,  12],
#        [  1,   0,   1,   0,  16,   0, 113,   0],
#        [ 13,   0,   0,   0,  97,   0,  15,   2]])

# %%
# reference http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
import itertools
import matplotlib.pyplot as plt

def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
#         print("Normalized confusion matrix")
#     else:
#         print('Confusion matrix, without normalization')

#     print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label',size=20)
    plt.xlabel('Predicted label',size=20)

# %%
PATH_TO_IMG = "../data/input_dataset"
class_names = sorted([folder for folder in os.listdir(PATH_TO_IMG)
                      if os.path.isdir(os.path.join(PATH_TO_IMG, folder))])

# %%
fig = plt.figure(figsize=(20, 6))

fig.add_subplot(1,2,1)
plot_confusion_matrix(ft_conf_mat, classes=class_names, title='Confusion matrix')

fig.add_subplot(1,2,2)
plot_confusion_matrix(ft_conf_mat, classes=class_names, normalize=True, title='Confusion matrix')

plt.savefig(os.path.join(PATH_TO_DF, "ft_confmat_VGG16.png"), bbox_inches='tight') # png 70kb vs jpg 135 kb

plt.show()

# %%
from sklearn.metrics import classification_report, accuracy_score

# print(classification_report(y_test, pred_categorical))
# print("The total accuracy is", accuracy_score(y_test, pred_categorical))
