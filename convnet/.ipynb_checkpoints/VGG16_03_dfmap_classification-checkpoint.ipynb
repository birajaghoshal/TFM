# %% [markdown]
# ## Mejoras
#
# Relativas a la posible mejora de los resultados analíticos:
#
# * uso de validación cruzada para selección de muestras
# * selección de mejores hiperparámetros en los algoritmos de clasificación
#
# Relativas a la mejora de los códigos Python:
#
# * optimización código / refactorización
# * guardar resultados modelos en estructuras (ficheros) ¿?
# * control de errores en cada parte del proceso

# %% [markdown]
# https://randomforests.wordpress.com/2014/02/02/basics-of-k-fold-cross-validation-and-gridsearchcv-in-scikit-learn/

# %%
import os
import pickle
import numpy as np

PATH_TO_LABELS_FILE = "../data/output_dataset"
LABELS = "img_labels"

PATH_TO_DF = "../data/output_convnet"

DF_MAP_relU = "VGG16_dfmap_relU_pca_pickle" # with relU activation function
DF_MAP_no_relU = "VGG16_dfmap_no_relU_pca_pickle" # without activation function

labels = []

with open(os.path.join(PATH_TO_LABELS_FILE,LABELS),'r') as f_img_labels:
    for line in f_img_labels:
        labels.append(line[:-1])

features_relU = pickle.load(open(os.path.join(PATH_TO_DF,DF_MAP_relU),'rb'))
features_no_relU = pickle.load(open(os.path.join(PATH_TO_DF,DF_MAP_no_relU),'rb'))

features_arr_relU = np.array(features_relU)
features_arr_no_relU = np.array(features_no_relU)
labels_arr = np.array(labels)

print("Deep features - deep feature map + relU")
print()
print("Structure dims: {0:d} x {1:d}".format(features_arr_relU.shape[0], features_arr_relU.shape[1]))
print()
print("N of deep features arrays (images): ", features_arr_relU.shape[0])
print()
print("N of deep features: ",features_arr_relU.shape[1])
print()
print(features_arr_relU) # array with deep features
print()
print()
print("Deep features - deep feature map no relU")
print()
print("Structure dims: {0:d} x {1:d}".format(features_arr_no_relU.shape[0], features_arr_no_relU.shape[1]))
print()
print("N of deep features arrays (images): ", features_arr_no_relU.shape[0])
print()
print("N of deep features: ",features_arr_no_relU.shape[1])
print()
print(features_arr_no_relU) # array with deep features
print()
print()
print("Image's labels")
print()
print("Structure: ", type(labels_arr))
print()
print("Nº of image labels (images): ", len(labels_arr))
print()
print(labels_arr) # img's label
# Out:
# Deep features - deep feature map + relU
#
# Structure dims: 5000 x 1000
#
# N of deep features arrays (images):  5000
#
# N of deep features:  1000
#
# [[ 0.01421037 -0.01555242 -0.00881162 ..., -0.01290644  0.01445942
#   -0.0054747 ]
#  [ 0.01199514 -0.00594742  0.00066701 ..., -0.00975538  0.00167974
#    0.01962632]
#  [ 0.01579151 -0.00059549  0.00241913 ..., -0.0405117  -0.00646415
#   -0.01172362]
#  ...,
#  [ 0.00187142 -0.00286333  0.02814319 ...,  0.01216433 -0.0025019
#   -0.01250323]
#  [ 0.00189918 -0.00251643  0.02762949 ...,  0.00493237  0.00218991
#    0.00545372]
#  [ 0.00224167 -0.00282383  0.03347716 ..., -0.00822048  0.00058355
#    0.00388236]]
#
#
# Deep features - deep feature map no relU
#
# Structure dims: 5000 x 200
#
# N of deep features arrays (images):  5000
#
# N of deep features:  200
#
# [[-0.01645746 -0.01567759  0.01135278 ..., -0.01829816 -0.0011744
#    0.00744266]
#  [-0.01205996 -0.00428557  0.00029339 ...,  0.01500359 -0.00822777
# ...

# %% [markdown]
# ## muestras REVISAR Y AÑADIR CROSS VALIDATION, UNIR ESTRUCTURAS DE DATOS¿?

# %%
from sklearn.model_selection import train_test_split

test_sample_size = 0.2

# http://scikit-learn.org/stable/modules/cross_validation.html
# http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html

# no pca
x_train, x_test, y_train, y_test = \
train_test_split(features_arr, labels_arr, test_size = test_sample_size, random_state = 42)

# pca
x_pca_train, x_pca_test, y_pca_train, y_pca_test = \
train_test_split(features_pca_arr, labels_arr, test_size = test_sample_size, random_state = 42)

# %% [markdown]
# Las muestras quedan así:
#
# con random_state 42 --> quedaran muestras identicas?

# %%
def print_info_dataset(x_train, x_test, y_train, y_test):

    print("Train sample:")
    print("x",type(x_train))
    print("x",x_train.shape)
    print()
    print("y",type(y_train))
    print("y",y_train.shape)
    print()
    print()
    print("test")
    print("x",type(x_test))
    print("x",x_test.shape)
    print()
    print("y",type(y_test))
    print("y",y_test.shape)

# %%
print("Data set without pca: ")
print_info_dataset(x_train, x_test, y_train, y_test)
print()
print("Data set with pca: ")
print_info_dataset(x_pca_train, x_pca_test, y_pca_train, y_pca_test)
# Out:
# Data set without pca:
# Train sample:
# x <class 'numpy.ndarray'>
# x (4000, 4096)
#
# y <class 'numpy.ndarray'>
# y (4000,)
#
#
# test
# x <class 'numpy.ndarray'>
# x (1000, 4096)
#
# y <class 'numpy.ndarray'>
# y (1000,)
#
# Data set with pca:
# Train sample:
# x <class 'numpy.ndarray'>
# x (4000, 800)
#
# y <class 'numpy.ndarray'>
# y (4000,)
#
#
# test
# x <class 'numpy.ndarray'>
# x (1000, 800)
#
# y <class 'numpy.ndarray'>
# y (1000,)

# %% [markdown]
# ## 1 Máquinas de soporte vectorial sin reducción de dimensiones

# %%
from sklearn.svm import LinearSVC

# model definition
SVM = LinearSVC()

# model training
SVM.fit(x_train, y_train)

# model predict
y_pred_svm = SVM.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
# %matplotlib inline

def conf_matrix(y_true,y_pred):
    
    # confusion matrix
    CM = confusion_matrix(y_true,y_pred)
    
    # image's categories
    true_labels = np.unique(y_true)
    pred_labels = np.unique(y_pred)
    
    # color pallete
    plt.imshow(CM[:-1,:-1], interpolation='nearest', cmap=plt.cm.Blues)
    
    plt.title("Confusion matrix", fontsize=16)
    
    cbar = plt.colorbar(fraction=0.046, pad=0.04)
    cbar.set_label('Number of images', rotation=270, labelpad=30, fontsize=12)
    
    xtick_marks = np.arange(len(true_labels))
    ytick_marks = np.arange(len(pred_labels))
    
    plt.xticks(xtick_marks, true_labels, rotation=90)
    plt.yticks(ytick_marks,pred_labels)
    
    plt.tight_layout()
    
    plt.ylabel('True label', fontsize=14)
    plt.xlabel('Predicted label', fontsize=14)
    
    fig_size = plt.rcParams["figure.figsize"]
    fig_size[0] = 12
    fig_size[1] = 12
    plt.rcParams["figure.figsize"] = fig_size

conf_matrix(y_test,y_pred_svm)

# %%
from sklearn.metrics import accuracy_score

def calc_metric(a,b):
    print("Accuracy: {0:0.1f}%".format(accuracy_score(a,b)*100))
    
calc_metric(y_test,y_pred_svm)
# Out:
# Accuracy: 90.5%

# %% [markdown]
# ## 2 Máquinas de soporte vectorial sin reducción de dimensiones

# %%
from sklearn.svm import LinearSVC

# model definition
SVM_PCA = LinearSVC()

# model training
SVM_PCA.fit(x_pca_train, y_pca_train)

# model predict
y_pca_pred_svm = SVM_PCA.predict(x_pca_test)

# %%
# %matplotlib inline
conf_matrix(y_pca_test,y_pca_pred_svm)

# %%
calc_metric(y_pca_test,y_pca_pred_svm)
# Out:
# Accuracy: 90.4%

# %% [markdown]
# ## 3 Árboles de decisión sin reducción de dimensiones

# %%
from sklearn.tree import DecisionTreeClassifier

# model definition
DTC = DecisionTreeClassifier()

# model training
DTC.fit(x_train, y_train)

# model predict
y_pred_dtc = DTC.predict(x_test)

# %%
# %matplotlib inline
conf_matrix(y_test,y_pred_dtc)

# %%
calc_metric(y_test,y_pred_dtc)
# Out:
# Accuracy: 71.0%

# %% [markdown]
# ## 4 Árboles de decisión con reducción de dimensiones

# %%
from sklearn.tree import DecisionTreeClassifier

# model definition
DTC_PCA = DecisionTreeClassifier()

# model training
DTC_PCA.fit(x_pca_train, y_pca_train)

# model predict
y_pca_pred_dtc = DTC_PCA.predict(x_pca_test)

# %%
# %matplotlib inline
conf_matrix(y_pca_test,y_pca_pred_dtc)

# %%
calc_metric(y_pca_test,y_pca_pred_dtc)
# Out:
# Accuracy: 75.0%

# %% [markdown]
# ## 5 Bosques aleatorios sin reducción de dimensiones

# %%
from sklearn.ensemble import RandomForestClassifier

# model definition
RFC = RandomForestClassifier()

# model training
RFC.fit(x_train, y_train)

# model predict
y_pred_rfc = RFC.predict(x_test)

# %%
# %matplotlib inline
conf_matrix(y_test,y_pred_rfc)

# %% [markdown]
# metricas

# %%
calc_metric(y_test,y_pred_rfc)
# Out:
# Accuracy: 78.6%

# %% [markdown]
# ## 6 Bosques aleatorios con reducción de dimensiones

# %%
from sklearn.ensemble import RandomForestClassifier

# model definition
RFC_PCA = RandomForestClassifier()

# model training
RFC_PCA.fit(x_pca_train, y_pca_train)

# model predict
y_pca_pred_rfc = RFC_PCA.predict(x_pca_test)

# %%
# %matplotlib inline
conf_matrix(y_pca_test,y_pca_pred_rfc)

# %%
calc_metric(y_pca_test,y_pca_pred_rfc)
# Out:
# Accuracy: 66.9%

# %% [markdown]
# Data with relU
#     * SVM
#     * DCT
#     * RFC
#
# Data with no activation function
#     * SVM
#     * DCT
#     * RFC
